# %% [markdown]
# # Word Vectorization - Lab
#
# ## Introduction
#
# In this lab, you'll tokenize and vectorize text documents, create and use a bag of words, and identify words unique to individual documents using TF-IDF vectorization.
#
#
# ## Objectives
#
# In this lab you will:
#
# - Implement tokenization and count vectorization from scratch
# - Implement TF-IDF from scratch
# - Use dimensionality reduction on vectorized text data to create and interpret visualizations
#
# ## Let's get started!
#
# Run the cell below to import everything necessary for this lab.

# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.manifold import TSNE
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt', quiet=True)
np.random.seed(0)

# %% [markdown]
# ### Our Corpus
#
# In this lab, we'll be working with 20 different documents, each containing song lyrics from either Garth Brooks or Kendrick Lamar albums.
#
# The songs are contained within the `data` subdirectory, contained within the same folder as this lab.  Each song is stored in a single file, with files ranging from `song1.txt` to `song20.txt`.
#
# To make it easy to read in all of the documents, use a list comprehension to create a list containing the name of every single song file in the cell below.

# %%
filenames = [f"data/song{i}.txt" for i in range(1, 21)]
filenames
# Out:
# ['data/song1.txt',
#  'data/song2.txt',
#  'data/song3.txt',
#  'data/song4.txt',
#  'data/song5.txt',
#  'data/song6.txt',
#  'data/song7.txt',
#  'data/song8.txt',
#  'data/song9.txt',
#  'data/song10.txt',
#  'data/song11.txt',
#  'data/song12.txt',
#  'data/song13.txt',
#  'data/song14.txt',
#  'data/song15.txt',
#  'data/song16.txt',
#  'data/song17.txt',
#  'data/song18.txt',
#  'data/song19.txt',
#  'data/song20.txt']

# %% [markdown]
# Next, let's import a single song to see what our text looks like so that we can make sure we clean and tokenize it correctly.
#
# Use the code in the cell below to read in the lyrics from `song18.txt` as a list of lines, just using vanilla Python:

# %%
# Import and print song18.txt
with open('data/song18.txt') as f:
    test_song = f.readlines()
    
test_song
# Out:
# ['[Kendrick Lamar:]\n',
#  "Two wrongs don't make us right away\n",
#  "Tell me something's wrong\n",
#  'Party all of our lives away\n',
#  'To take you on\n',
#  '[Zacari:]\n',
#  'Oh, baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'All night (all night, all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  'All night (all night, all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  '[Babes Wodumo:]\n',
#  'Oh my word oh my gosh oh my word (Oh my gosh)\n',
#  'Oh my word oh my gosh oh my word (Oh my gosh)\n',
#  'Oh my word oh my gosh oh my word (Oh my gosh)\n',
#  'Oh my word oh my gosh oh my word (Oh my gosh)\n',
#  'Everybody say kikiritikiki (kikiritikiki)\n',
#  'Everybody say kikiritikiki (kikiritikiki)\n',
#  'Everybody say kikiritikiki (kikiritikiki)\n',
#  'Everybody say kikiritikiki (kikiritikiki)\n',
#  "Ung'bambe, ung'dedele. Ung'bhasobhe, ung'gudluke\n",
#  "Ung'bambe, ung'dedele. Ung'bhasobhe, ung'gudluke\n",
#  "Ung'bambe, ung'dedele. Ung'bhasobhe, ung'gudluke\n",
#  "Ung'bambe, ung'dedele. Ung'bhasobhe, ung'gudluke\n",
#  '[Zacari:]\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'All night (all night all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  'All night (all night all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  '[Kendrick Lamar:]\n',
#  '(We go)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  '[?]\n',
#  '[Zacari:]\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'All night (all night all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  'All night (all night all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n']

# %% [markdown]
# ### Tokenizing our Data
#
# Before we can create a bag of words or vectorize each document, we need to clean it up and split each song into an array of individual words.
#
# Consider the following sentences from the example above:
#
# `"Two wrongs don't make us right away\n", "Tell me something's wrong\n"`
#
# After tokenization, this should look like:
#
# `['two', 'wrongs', 'dont', 'make', 'us', 'right', 'away', 'tell', 'me', 'somethings', 'wrong']`
#
# Tokenization is pretty tedious if we handle it manually, and would probably make use of regular expressions, which is outside the scope of this lab. In order to keep this lab moving, we'll use a library function to clean and tokenize our data so that we can move onto vectorization.
#
# Tokenization is a required task for just about any Natural Language Processing (NLP) task, so great industry-standard tools exist to tokenize things for us, so that we can spend our time on more important tasks without getting bogged down hunting every special symbol or punctuation in a massive dataset. For this lab, we'll make use of the tokenizer in the amazing `nltk` library, which is short for _Natural Language Tool Kit_.
#
# **_NOTE:_** NLTK requires extra installation methods to be run the first time certain methods are used.  If `nltk` throws you an error about needing to install additional packages, follow the instructions in the error message to install the dependencies, and then rerun the cell.

# %% [markdown]
# Before we tokenize, however, we need to do one more step! Computers are very particular about strings. If we tokenized our data in its current state, we would run into the following problems:
#
# - Counting things that aren't actually words.  In the example above, `"[Kendrick Lamar:]"` is a note specifying who is speaking, not a lyric contained in the actual song, so it should be removed.
# - Punctuation and capitalization would mess up our word counts. To the Python interpreter, `all`, `All`, and `(all` are unique words, and would all be counted separately.  We need to remove punctuation and capitalization, so that all words will be counted correctly.
#
# Before we tokenize our songs, we'll do only a small manual bit of cleaning.
#
# In the cell below, write a function to:
# - remove lines that just contain `['artist names']`
# - join the list of strings into one big string for the entire song
# - remove newline characters `\n`
# - remove the following punctuation marks: `",.'?!()"`
# - make every word lowercase
#
# Test the function on `test_song` to show that it has successfully removed `'[Kendrick Lamar:]'` and other instances of artist names from the song, and is returning the song as one string (NOT a list of strings) with newlines (`\n`) and punctuation removed and every word in lowercase.

# %%
import re
import string
def clean_song(song):
    song_text = ''.join(song)
    song_text = re.sub(r'\[.*?\]:', '', song_text)
    
    song_text = song_text.translate(str.maketrans('', '', string.punctuation))
    song_text = song_text.lower()
    
    song_text = song_text.replace('\n', ' ')
    
    return song_text

clean_test_song = clean_song(test_song)
print(type(clean_test_song))
# Out:
# <class 'str'>

# %% [markdown]
# Great! Now, we can use `nltk`'s `word_tokenize()` function on the song string to get a fully tokenized version of the song. Test this function on `clean_test_song` to ensure that the function works.

# %%
from nltk.tokenize import word_tokenize

clean_test_song = clean_song(test_song)
tokenized_test_song = word_tokenize(clean_test_song)
tokenized_test_song
# Out:
# ['kendrick',
#  'lamar',
#  'two',
#  'wrongs',
#  'dont',
#  'make',
#  'us',
#  'right',
#  'away',
#  'tell',
#  'me',
#  'somethings',
#  'wrong',
#  'party',
#  'all',
#  'of',
#  'our',
#  'lives',
#  'away',
#  'to',
#  'take',
#  'you',
#  'on',
#  'zacari',
#  'oh',
#  'baby',
#  'i',
#  'want',
#  'you',
#  'baby',
#  'i',
#  'need',
#  'you',
#  'i',
#  'wan',
#  'na',
#  'see',
#  'you',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'baby',
#  'i',
#  'want',
#  'you',
#  'baby',
#  'i',
#  'need',
#  'you',
#  'i',
#  'wan',
#  'na',
#  'see',
#  'you',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'your',
#  'bodys',
#  'on',
#  'fire',
#  'and',
#  'your',
#  'drinks',
#  'on',
#  'ice',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'your',
#  'bodys',
#  'on',
#  'fire',
#  'and',
#  'your',
#  'drinks',
#  'on',
#  'ice',
#  'babes',
#  'wodumo',
#  'oh',
#  'my',
#  'word',
#  'oh',
#  'my',
#  'gosh',
#  'oh',
#  'my',
#  'word',
#  'oh',
#  'my',
#  'gosh',
#  'oh',
#  'my',
#  'word',
#  'oh',
#  'my',
#  'gosh',
#  'oh',
#  'my',
#  'word',
#  'oh',
#  'my',
#  'gosh',
#  'oh',
#  'my',
#  'word',
#  'oh',
#  'my',
#  'gosh',
#  'oh',
#  'my',
#  'word',
#  'oh',
#  'my',
#  'gosh',
#  'oh',
#  'my',
#  'word',
#  'oh',
#  'my',
#  'gosh',
#  'oh',
#  'my',
#  'word',
#  'oh',
#  'my',
#  'gosh',
#  'everybody',
#  'say',
#  'kikiritikiki',
#  'kikiritikiki',
#  'everybody',
#  'say',
#  'kikiritikiki',
#  'kikiritikiki',
#  'everybody',
#  'say',
#  'kikiritikiki',
#  'kikiritikiki',
#  'everybody',
#  'say',
#  'kikiritikiki',
#  'kikiritikiki',
#  'ungbambe',
#  'ungdedele',
#  'ungbhasobhe',
#  'unggudluke',
#  'ungbambe',
#  'ungdedele',
#  'ungbhasobhe',
#  'unggudluke',
#  'ungbambe',
#  'ungdedele',
#  'ungbhasobhe',
#  'unggudluke',
#  'ungbambe',
#  'ungdedele',
#  'ungbhasobhe',
#  'unggudluke',
#  'zacari',
#  'baby',
#  'i',
#  'want',
#  'you',
#  'baby',
#  'i',
#  'need',
#  'you',
#  'i',
#  'wan',
#  'na',
#  'see',
#  'you',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'baby',
#  'i',
#  'want',
#  'you',
#  'baby',
#  'i',
#  'need',
#  'you',
#  'i',
#  'wan',
#  'na',
#  'see',
#  'you',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'your',
#  'bodys',
#  'on',
#  'fire',
#  'and',
#  'your',
#  'drinks',
#  'on',
#  'ice',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'your',
#  'bodys',
#  'on',
#  'fire',
#  'and',
#  'your',
#  'drinks',
#  'on',
#  'ice',
#  'kendrick',
#  'lamar',
#  'we',
#  'go',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'high',
#  'up',
#  'zacari',
#  'baby',
#  'i',
#  'want',
#  'you',
#  'baby',
#  'i',
#  'need',
#  'you',
#  'i',
#  'wan',
#  'na',
#  'see',
#  'you',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'baby',
#  'i',
#  'want',
#  'you',
#  'baby',
#  'i',
#  'need',
#  'you',
#  'i',
#  'wan',
#  'na',
#  'see',
#  'you',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'baby',
#  'i',
#  'wan',
#  'na',
#  'go',
#  'out',
#  'yeah',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'your',
#  'bodys',
#  'on',
#  'fire',
#  'and',
#  'your',
#  'drinks',
#  'on',
#  'ice',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'all',
#  'night',
#  'your',
#  'bodys',
#  'on',
#  'fire',
#  'and',
#  'your',
#  'drinks',
#  'on',
#  'ice']

# %% [markdown]
# Great! Now that we can tokenize our songs, we can move onto vectorization.
#
#
# ### Count Vectorization
#
# Machine Learning algorithms don't understand strings. However, they do understand math, which means they understand vectors and matrices.  By **_Vectorizing_** the text, we just convert the entire text into a vector, where each element in the vector represents a different word. The vector is the length of the entire vocabulary -- usually, every word that occurs in the English language, or at least every word that appears in our corpus.  Any given sentence can then be represented as a vector where all the vector is 1 (or some other value) for each time that word appears in the sentence.
#
# Consider the following example:
#
# <center>"I scream, you scream, we all scream for ice cream."</center>
#
# | 'aardvark' | 'apple' | [...] | 'I' | 'you' | 'scream' | 'we' | 'all' | 'for' | 'ice' | 'cream' | [...] | 'xylophone' | 'zebra' |
# |:----------:|:-------:|:-----:|:---:|:-----:|:--------:|:----:|:-----:|:-----:|:-----:|:-------:|:-----:|:-----------:|:-------:|
# |      0     |    0    |   0   |  1  |   1   |     3    |   1  |   1   |   1   |   1   |    1    |   0   |      0      |    0    |
#
# This is called a **_Sparse Representation_**, since the strong majority of the columns will have a value of 0.  Note that elements corresponding to words that do not occur in the sentence have a value of 0, while words that do appear in the sentence have a value of 1 (or 1 for each time it appears in the sentence).
#
# Alternatively, we can represent this sentence as a plain old Python dictionary of word frequency counts:
#
# ```python
# BoW = {
#     'I':1,
#     'you':1,
#     'scream':3,
#     'we':1,
#     'all':1,
#     'for':1,
#     'ice':1,
#     'cream':1
# }
# ```
#
# Both of these are examples of **_Count Vectorization_**. They allow us to represent a sentence as a vector, with each element in the vector corresponding to how many times that word is used.
#
# #### Positional Information and Bag of Words
#
# Notice that when we vectorize a sentence this way, we lose the order that the words were in.  This is the **_Bag of Words_** approach mentioned earlier.  Note that sentences that contain the same words will create the same vectors, even if they mean different things -- e.g. `'cats are scared of dogs'` and `'dogs are scared of cats'` would both produce the exact same vector, since they contain the same words.

# %% [markdown]
# In the cell below, create a function that takes in a tokenized, cleaned song and returns a count vectorized representation of it as a Python dictionary.
#
# **_Hint:_**  Consider using a `set()` since you'll need each unique word in the tokenized song!

# %%
def count_vectorize(tokenized_song):
    word_count = {}
    
    for word in tokenized_song:
        if word in word_count:
            word_count[word] += 1  
        else:
            word_count[word] = 1  
    
    return word_count
    

test_vectorized = count_vectorize(tokenized_test_song)
print(test_vectorized)
# Out:
# {'kendrick': 2, 'lamar': 2, 'two': 1, 'wrongs': 1, 'dont': 1, 'make': 1, 'us': 1, 'right': 1, 'away': 2, 'tell': 1, 'me': 1, 'somethings': 1, 'wrong': 1, 'party': 1, 'all': 25, 'of': 1, 'our': 1, 'lives': 1, 'to': 1, 'take': 1, 'you': 19, 'on': 13, 'zacari': 3, 'oh': 17, 'baby': 24, 'i': 30, 'want': 6, 'need': 6, 'wan': 18, 'na': 18, 'see': 6, 'go': 13, 'out': 12, 'yeah': 12, 'night': 24, 'your': 12, 'bodys': 6, 'fire': 6, 'and': 6, 'drinks': 6, 'ice': 6, 'babes': 1, 'wodumo': 1, 'my': 16, 'word': 8, 'gosh': 8, 'everybody': 4, 'say': 4, 'kikiritikiki': 8, 'ungbambe': 4, 'ungdedele': 4, 'ungbhasobhe': 4, 'unggudluke': 4, 'we': 1, 'high': 16, 'up': 16}

# %% [markdown]
# Great! You've just successfully vectorized your first text document! Now, let's look at a more advanced type of vectorization, TF-IDF!
#
# ### TF-IDF Vectorization
#
# TF-IDF stands for **_Term Frequency, Inverse Document Frequency_**.  This is a more advanced form of vectorization that weighs each term in a document by how unique it is to the given document it is contained in, which allows us to summarize the contents of a document using a few key words.  If the word is used often in many other documents, it is not unique, and therefore probably not too useful if we wanted to figure out how this document is unique in relation to other documents. Conversely, if a word is used many times in a document, but rarely in all the other documents we are considering, then it is likely a good indicator for telling us that this word is important to the document in question.
#
# The formula TF-IDF uses to determine the weights of each term in a document is **_Term Frequency_** multiplied by **_Inverse Document Frequency_**. We just calculated our Term Frequency above with Count Vectorization!

# %% [markdown]
# Now that we have this, we can easily calculate _Inverse Document Frequency_. Note that this will need ALL of our documents (aka our songs), not just an individual document - so we'll put off testing this function for now.
#
# In the cell below, complete a function that takes in a list of tokenized songs, with each item in the list being a clean, tokenized version of the song. The function should return a dictionary containing the inverse document frequency values for each word.
#
# The formula for Inverse Document Frequency is:
# <br>
# <br>
# $$\large \text{IDF}(t) =  log_e(\frac{\text{Total Number of Documents}}{\text{Number of Documents with } t \text{ in it}})$$

# %%
import math

def inverse_document_frequency(list_of_token_songs):
    total_documents = len(list_of_token_songs)
    
    # Dictionary to store IDF values
    idf_values = {}
    
    # Loop through each song
    for song in list_of_token_songs:
        unique_words = set(song) 
        
        # For each unique word in the song, update the IDF count
        for word in unique_words:
            if word not in idf_values:
                idf_values[word] = 1  
            else:
                idf_values[word] += 1  
    
    # Now, calculate the IDF for each word
    for word in idf_values:
        idf_values[word] = math.log(total_documents / idf_values[word])
    
    return idf_values

# %% [markdown]
# ### Computing TF-IDF
#
# Now that we can compute both Term Frequency and Inverse Document Frequency, computing an overall TF-IDF value is simple! All we need to do is multiply the two values.
#
# In the cell below, complete the `tf_idf()` function.  This function should take in a list of tokenized songs, just as the `inverse_document_frequency()` function did.  This function returns a new list of dictionaries, with each dictionary containing the tf-idf vectorized representation of a corresponding song document. You'll need to calculate the term frequency for each song using the `count_vectorize()` function we defined above.
#
# **_NOTE:_** Each document should contain the full vocabulary of the entire combined corpus! So, even if a song doesn't have the word "kikiritikiki" (a vocalization in our test song), it should have a dictionary entry with that word as the key and `0` as the value.

# %%
def tf_idf(list_of_token_songs):
    tf_vectors = [count_vectorize(song) for song in list_of_token_songs]
    
    idf_values = inverse_document_frequency(list_of_token_songs)
    
    # Create a list to store the TF-IDF vectors for each song
    tf_idf_vectors = []
    
    # Get the complete vocabulary from the IDF values (this includes all words in the corpus)
    vocabulary = idf_values.keys()
    
    # Compute TF-IDF for each song
    for tf_vector in tf_vectors:
        # Initialize an empty dictionary for the TF-IDF vector
        tf_idf_vector = {}
        
        # For each word in the vocabulary, calculate its TF-IDF
        for word in vocabulary:
            # Term Frequency (TF)
            tf = tf_vector.get(word, 0) 
            
            # Inverse Document Frequency (IDF)
            idf = idf_values.get(word, 0) 
            
            # TF-IDF = TF * IDF
            tf_idf_vector[word] = tf * idf
        
        # Add the TF-IDF vector for the current song to the list
        tf_idf_vectors.append(tf_idf_vector)
    
    return tf_idf_vectors

# %% [markdown]
# ### Vectorizing All Documents
#
# Now that we've created all the necessary helper functions, we can load in all of our documents and run each through the vectorization pipeline we've just created.
#
# In the cell below, complete the `main()` function.  This function should take in a list of file names (provided for you in the `filenames` list we created at the start), and then:
#
# - Read in each document into a list of raw songs (where each song is a list of strings)
# - Tokenize each document into a list of cleaned and tokenized songs
# - Return a list of dictionaries vectorized using `tf-idf`, where each dictionary is a vectorized representation of each song

# %%
def main(filenames):
    raw_songs = []
    
    # Loop through each filename and read the contents of the song
    for filename in filenames:
        with open(filename, 'r') as file:
            song = file.readlines()  
            raw_songs.append(song)   
            
    # Tokenize each document into a list of cleaned and tokenized songs
    tokenized_songs = []
    
    for song in raw_songs:
        cleaned_song = clean_song(song)  # Clean the song
        tokenized_song = word_tokenize(cleaned_song) 
        tokenized_songs.append(tokenized_song) 
    
    # Vectorize the tokenized songs using TF-IDF
    tf_idf_vectors = tf_idf(tokenized_songs)  
    
    return tf_idf_vectors

tf_idf_all_docs = main(filenames)
tf_idf_all_docs
# Out:
# [{'sea': 8.987196820661973,
#   'valentines': 2.995732273553991,
#   'lent': 2.995732273553991,
#   'cup': 8.987196820661973,
#   'hands': 1.8971199848858813,
#   'scenes': 2.995732273553991,
#   'dreams': 1.8971199848858813,
#   'girl': 1.2039728043259361,
#   'passage': 8.987196820661973,
#   '9': 2.302585092994046,
#   'theres': 1.0498221244986776,
#   'thunder': 2.995732273553991,
#   'signed': 2.995732273553991,
#   'occurred': 2.995732273553991,
#   'ride': 1.8971199848858813,
#   'ore': 8.987196820661973,
#   'heaven': 6.907755278982138,
#   'was': 4.1588830833596715,
#   'queens': 2.995732273553991,
#   'walked': 2.995732273553991,
#   'on': 0.05129329438755048,
#   'know': 1.0700248318161971,
#   'my': 1.7231316643698174,
#   'or': 5.545177444479562,
#   'his': 1.6094379124341003,
#   'sad': 2.995732273553991,
#   'took': 4.605170185988092,
#   'rodeo': 2.995732273553991,
#   'together': 2.302585092994046,
#   'bed': 2.995732273553991,
#   'born': 6.907755278982138,
#   'so': 1.5970153924355432,
#   'she': 1.3862943611198906,
#   'made': 3.7942399697717626,
#   'from': 2.0794415416798357,
#   'runnin': 4.1588830833596715,
#   'green': 2.302585092994046,
#   'raised': 2.995732273553991,
#   'ventura': 2.995732273553991,
#   'mind': 1.6094379124341003,
#   'fiery': 8.987196820661973,
#   'a': 0.8125946474888747,
#   'be': 0.43078291609245434,
#   'rode': 2.995732273553991,
#   'forget': 2.302585092994046,
#   'and': 0.7693994158132572,
#   'hold': 1.6094379124341003,
#   'to': 0.5642262382630553,
#   'song': 2.302585092994046,
#   'passed': 2.995732273553991,
#   'me': 0.44628710262841953,
#   'maple': 2.995732273553991,
#   'they': 1.7935110022668612,
#   'herb': 2.995732273553991,
#   'enshrined': 2.995732273553991,
#   'fourteen': 2.995732273553991,
#   'through': 3.1494663734960326,
#   '8teen': 32.9530550090939,
#   'you': 0.15387988316265144,
#   'moves': 2.995732273553991,
#   'beneath': 2.302585092994046,
#   'night': 4.1588830833596715,
#   'strings': 2.995732273553991,
#   'words': 5.991464547107982,
#   'beside': 2.995732273553991,
#   'such': 2.995732273553991,
#   'that': 0.9751135769866497,
#   'luck': 8.987196820661973,
#   'where': 1.6094379124341003,
#   'an': 1.6094379124341003,
#   'pristine': 2.995732273553991,
#   'will': 7.588479939543525,
#   'silver': 2.995732273553991,
#   'blessing': 8.987196820661973,
#   'said': 2.302585092994046,
#   'day': 2.0996442489973552,
#   'gods': 8.987196820661973,
#   'how': 0.5978370007556204,
#   'out': 0.3566749439387324,
#   'rolled': 2.302585092994046,
#   'the': 3.9004543079465988,
#   'could': 1.8971199848858813,
#   'we': 3.4657359027997265,
#   'every': 2.772588722239781,
#   'when': 0.3566749439387324,
#   'cross': 2.995732273553991,
#   'new': 1.8971199848858813,
#   'teach': 8.987196820661973,
#   'now': 1.6094379124341003,
#   'wild': 5.691359954657644,
#   'their': 1.8971199848858813,
#   'everyone': 6.907755278982138,
#   'plate': 2.302585092994046,
#   'he': 4.1588830833596715,
#   'gates': 8.987196820661973,
#   'jc': 2.995732273553991,
#   'there': 2.4079456086518722,
#   'adds': 11.982929094215963,
#   'water': 2.302585092994046,
#   'all': 0.8925742052568391,
#   'kept': 2.302585092994046,
#   'borderline': 2.995732273553991,
#   'jesus': 2.995732273553991,
#   'free': 5.691359954657644,
#   'big': 1.3862943611198906,
#   'red': 1.8971199848858813,
#   'her': 1.2039728043259361,
#   'state': 2.995732273553991,
#   'as': 1.2039728043259361,
#   'gift': 6.907755278982138,
#   'japan': 2.995732273553991,
#   'uncle': 2.995732273553991,
#   'pearly': 8.987196820661973,
#   'nimbus': 2.995732273553991,
#   'heard': 4.605170185988092,
#   'time': 1.1956740015112408,
#   'trinity': 8.987196820661973,
#   'letters': 2.995732273553991,
#   'for': 1.7231316643698174,
#   'underlined': 2.995732273553991,
#   'frozen': 2.995732273553991,
#   'about': 1.2039728043259361,
#   'highway': 2.302585092994046,
#   'in': 0.5268025782891318,
#   'bullet': 2.302585092994046,
#   'oh': 1.3862943611198906,
#   'call': 9.656627474604601,
#   'leaf': 2.995732273553991,
#   'up': 1.4266997757549296,
#   'hummed': 2.995732273553991,
#   'of': 1.7260924347106852,
#   'forever': 4.605170185988092,
#   'miracle': 2.995732273553991,
#   'vincent': 2.995732273553991,
#   'sunshine': 2.995732273553991,
#   'spent': 2.995732273553991,
#   'ear': 2.995732273553991,
#   'it': 2.2314355131420975,
#   'six': 2.995732273553991,
#   'runneth': 8.987196820661973,
#   'team': 2.302585092994046,
#   'never': 1.8325814637483102,
#   'each': 6.907755278982138,
#   'though': 2.302585092994046,
#   'working': 0.0,
#   'aching': 0.0,
#   'are': 0.0,
#   'doesnt': 0.0,
#   'over': 0.0,
#   'lane': 0.0,
#   'wanting': 0.0,
#   'guess': 0.0,
#   'friends': 0.0,
#   'beer': 0.0,
#   'back': 0.0,
#   'talking': 0.0,
#   'shes': 0.0,
#   'starts': 0.0,
#   'should': 0.0,
#   'cowboys': 0.0,
#   'head': 0.0,
#   'soon': 0.0,
#   'wait': 0.0,
#   'work': 0.0,
#   'again': 0.0,
#   'cause': 0.0,
#   'begins': 0.0,
#   'jack': 0.0,
#   'ends': 0.0,
#   'leave': 0.0,
#   'going': 0.0,
#   'home': 0.0,
#   'were': 0.0,
#   'fun': 0.0,
#   'threatening': 0.0,
#   'late': 0.0,
#   'wearing': 0.0,
#   'have': 0.0,
#   'busting': 0.0,
#   'sleep': 0.0,
#   'morning': 0.0,
#   'party': 0.0,
#   'with': 0.0,
#   'theyre': 0.0,
#   'who': 0.0,
#   'just': 0.0,
#   'yeah': 0.0,
#   'shirt': 0.0,
#   'goes': 0.0,
#   'nightstand': 0.0,
#   'its': 0.0,
#   'yes': 0.0,
#   'road': 0.0,
#   'ive': 0.0,
#   'this': 0.0,
#   'breakfast': 0.0,
#   'kitchen': 0.0,
#   'keep': 0.0,
#   'say': 0.0,
#   'is': 0.0,
#   'been': 0.0,
#   'thats': 0.0,
#   'im': 0.0,
#   'foreman': 0.0,
#   'two': 0.0,
#   'way': 0.0,
#   'buddies': 0.0,
#   'crime': 0.0,
#   'open': 0.0,
#   'last': 0.0,
#   'feeling': 0.0,
#   'swing': 0.0,
#   'right': 0.0,
#   'knocks': 0.0,
#   'get': 0.0,
#   'need': 0.0,
#   'four': 0.0,
#   'car': 0.0,
#   'worked': 0.0,
#   'down': 0.0,
#   'turns': 0.0,
#   'something': 0.0,
#   'sees': 0.0,
#   'says': 0.0,
#   'would': 0.0,
#   'face': 0.0,
#   'beach': 0.0,
#   'em': 0.0,
#   'gets': 0.0,
#   'problem': 0.0,
#   'thieving': 0.0,
#   'dessert': 0.0,
#   'monday': 0.0,
#   'ill': 0.0,
#   'knows': 0.0,
#   'dinner': 0.0,
#   'gone': 0.0,
#   'heading': 0.0,
#   'pickup': 0.0,
#   'perfect': 0.0,
#   'plan': 0.0,
#   'complete': 0.0,
#   'somethings': 0.0,
#   'gifted': 0.0,
#   'amen': 0.0,
#   'switch': 0.0,
#   'score': 0.0,
#   'youre': 0.0,
#   'lets': 0.0,
#   'evening': 0.0,
#   'set': 0.0,
#   'flash': 0.0,
#   'must': 0.0,
#   'light': 0.0,
#   'afternoon': 0.0,
#   'like': 0.0,
#   'happened': 0.0,
#   'clydes': 0.0,
#   'seen': 0.0,
#   'him': 0.0,
#   'once': 0.0,
#   'petty': 0.0,
#   'thousand': 0.0,
#   'clyde': 0.0,
#   'standing': 0.0,
#   'times': 0.0,
#   'swaps': 0.0,
#   'hit': 0.0,
#   'more': 0.0,
#   'let': 0.0,
#   'floor': 0.0,
#   'sleight': 0.0,
#   'grabs': 0.0,
#   'end': 0.0,
#   'seems': 0.0,
#   'bout': 0.0,
#   'not': 0.0,
#   'if': 0.0,
#   'sands': 0.0,
#   'run': 0.0,
#   'find': 0.0,
#   'hand': 0.0,
#   'but': 0.0,
#   'jump': 0.0,
#   'armored': 0.0,
#   'before': 0.0,
#   'stopping': 0.0,
#   'dealer': 0.0,
#   'away': 0.0,
#   'joann': 0.0,
#   'guards': 0.0,
#   'window': 0.0,
#   'na': 0.0,
#   'happy': 0.0,
#   'west': 0.0,
#   'conniving': 0.0,
#   'hes': 0.0,
#   'at': 0.0,
#   'hustle': 0.0,
#   'asks': 0.0,
#   'man': 0.0,
#   'bang': 0.0,
#   'someday': 0.0,
#   'hiding': 0.0,
#   'see': 0.0,
#   'good': 0.0,
#   'door': 0.0,
#   'guard': 0.0,
#   'shows': 0.0,
#   'money': 0.0,
#   'cash': 0.0,
#   'desert': 0.0,
#   'master': 0.0,
#   'house': 0.0,
#   'meet': 0.0,
#   'friday': 0.0,
#   'bags': 0.0,
#   'bangs': 0.0,
#   'play': 0.0,
#   'doors': 0.0,
#   'both': 0.0,
#   'ways': 0.0,
#   'gon': 0.0,
#   'fire': 0.0,
#   'rest': 0.0,
#   'what': 0.0,
#   'after': 0.0,
#   'driving': 0.0,
#   'talk': 0.0,
#   'hell': 0.0,
#   'fought': 0.0,
#   'lady': 0.0,
#   'high': 0.0,
#   'better': 0.0,
#   'crazy': 0.0,
#   'hope': 0.0,
#   'burning': 0.0,
#   'whiskey': 0.0,
#   'wine': 0.0,
#   'rejoin': 0.0,
#   'polite': 0.0,
#   'probably': 0.0,
#   'damn': 0.0,
#   'desire': 0.0,
#   'walking': 0.0,
#   'handsome': 0.0,
#   'no': 0.0,
#   'try': 0.0,
#   'always': 0.0,
#   'mans': 0.0,
#   'nice': 0.0,
#   'hoping': 0.0,
#   'show': 0.0,
#   'listens': 0.0,
#   'best': 0.0,
#   'dont': 0.0,
#   'refined': 0.0,
#   'pretty': 0.0,
#   'sure': 0.0,
#   'than': 0.0,
#   'miss': 0.0,
#   'loved': 0.0,
#   'knowing': 0.0,
#   'missing': 0.0,
#   'patient': 0.0,
#   'romantic': 0.0,
#   'same': 0.0,
#   'i': 0.0,
#   'showing': 0.0,
#   'move': 0.0,
#   'pass': 0.0,
#   'one': 0.0,
#   'ones': 0.0,
#   'nowhere': 0.0,
#   'hide': 0.0,
#   'unleash': 0.0,
#   'chosen': 0.0,
#   'storm': 0.0,
#   'drumming': 0.0,
#   'life': 0.0,
#   'pissed': 0.0,
#   'give': 0.0,
#   'waited': 0.0,
#   'young': 0.0,
#   'makin': 0.0,
#   'prove': 0.0,
#   'different': 0.0,
#   'them': 0.0,
#   'running': 0.0,
#   'some': 0.0,
#   'coming': 0.0,
#   'pure': 0.0,
#   'hear': 0.0,
#   'ever': 0.0,
#   'adrenaline': 0.0,
#   'ready': 0.0,
#   'chance': 0.0,
#   'multitudes': 0.0,
#   'whole': 0.0,
#   'kill': 0.0,
#   'dance': 0.0,
#   'dial': 0.0,
#   'want': 0.0,
#   'fates': 0.0,
#   'god': 0.0,
#   'long': 0.0,
#   'kickin': 0.0,
#   'forgotten': 0.0,
#   'got': 0.0,
#   'youve': 0.0,
#   'your': 0.0,
#   'inside': 0.0,
#   'drummer': 0.0,
#   'world': 0.0,
#   'byway': 0.0,
#   'off': 0.0,
#   'has': 0.0,
#   'beast': 0.0,
#   'stretch': 0.0,
#   'standin': 0.0,
#   'done': 0.0,
#   'lift': 0.0,
#   'knees': 0.0,
#   'second': 0.0,
#   'come': 0.0,
#   'desperate': 0.0,
#   'really': 0.0,
#   'true': 0.0,
#   'loves': 0.0,
#   'color': 0.0,
#   'changed': 0.0,
#   'isnt': 0.0,
#   'hed': 0.0,
#   'truly': 0.0,
#   'whoever': 0.0,
#   'prayer': 0.0,
#   'take': 0.0,
#   'shoulder': 0.0,
#   'lanes': 0.0,
#   'sitting': 0.0,
#   'us': 0.0,
#   'guys': 0.0,
#   'hers': 0.0,
#   'realize': 0.0,
#   'knew': 0.0,
#   'alright': 0.0,
#   'today': 0.0,
#   'fast': 0.0,
#   'can': 0.0,
#   'hard': 0.0,
#   'oclock': 0.0,
#   'nothings': 0.0,
#   'worse': 0.0,
#   'everything': 0.0,
#   'simply': 0.0,
#   'youd': 0.0,
#   'looks': 0.0,
#   'tonight': 0.0,
#   'crawl': 0.0,
#   'traffic': 0.0,
#   'finally': 0.0,
#   'five': 0.0,
#   'then': 0.0,
#   'falls': 0.0,
#   'wreck': 0.0,
#   'close': 0.0,
#   'much': 0.0,
#   'do': 0.0,
#   'tell': 0.0,
#   'crash': 0.0,
#   'changes': 0.0,
#   'model': 0.0,
#   'dying': 0.0,
#   'whoa': 0.0,
#   'lay': 0.0,
#   'save': 0.0,
#   'name': 0.0,
#   'explain': 0.0,
#   'heart': 0.0,
#   'love': 0.0,
#   'counting': 0.0,
#   'quite': 0.0,
#   'smile': 0.0,
#   'circumstance': 0.0,
#   'baby': 0.0,
#   'kind': 0.0,
#   'may': 0.0,
#   'hazy': 0.0,
#   'thinking': 0.0,
#   'known': 0.0,
#   'style': 0.0,
#   'pray': 0.0,
#   'cant': 0.0,
#   'black': 0.0,
#   'drive': 0.0,
#   'moving': 0.0,
#   'blind': 0.0,
#   'blue': 0.0,
#   'romance': 0.0,
#   'swore': 0.0,
#   'go': 0.0,
#   'victim': 0.0,
#   'brand': 0.0,
#   'comes': 0.0,
#   'trance': 0.0,
#   'felt': 0.0,
#   'shake': 0.0,
#   'youll': 0.0,
#   'fool': 0.0,
#   'things': 0.0,
#   'stubborn': 0.0,
#   'rules': 0.0,
#   'make': 0.0,
#   'pride': 0.0,
#   'anything': 0.0,
#   'trying': 0.0,
#   'settle': 0.0,
#   'ask': 0.0,
#   'push': 0.0,
#   'walls': 0.0,
#   'wont': 0.0,
#   'fall': 0.0,
#   'wrong': 0.0,
#   'freedom': 0.0,
#   'beg': 0.0,
#   'am': 0.0,
#   'figure': 0.0,
#   'maybe': 0.0,
#   'stick': 0.0,
#   'repeat': 0.0,
#   'shell': 0.0,
#   'around': 0.0,
#   'building': 0.0,
#   'space': 0.0,
#   'id': 0.0,
#   'start': 0.0,
#   'spending': 0.0,
#   'put': 0.0,
#   'another': 0.0,
#   'onto': 0.0,
#   'ta': 0.0,
#   'siena': 0.0,
#   'wherever': 0.0,
#   'cabanas': 0.0,
#   'means': 0.0,
#   'vienna': 0.0,
#   'south': 0.0,
#   'well': 0.0,
#   'sundown': 0.0,
#   'needs': 0.0,
#   'bet': 0.0,
#   'champaignurbana': 0.0,
#   'sweet': 0.0,
#   'even': 0.0,
#   'atlanta': 0.0,
#   'indiana': 0.0,
#   'wake': 0.0,
#   'still': 0.0,
#   'loving': 0.0,
#   'swear': 0.0,
#   'western': 0.0,
#   'havana': 0.0,
#   'track': 0.0,
#   'lord': 0.0,
#   'unwind': 0.0,
#   'montana': 0.0,
#   'chantin': 0.0,
#   'alabama': 0.0,
#   'laughing': 0.0,
#   'singing': 0.0,
#   'enough': 0.0,
#   'somewhere': 0.0,
#   'savannah': 0.0,
#   'rocking': 0.0,
#   'guyana': 0.0,
#   'our': 0.0,
#   'here': 0.0,
#   'louisiana': 0.0,
#   'rockin': 0.0,
#   'pajamas': 0.0,
#   'wan': 0.0,
#   'rollin': 0.0,
#   'muncie': 0.0,
#   'snakin': 0.0,
#   'dancing': 0.0,
#   'sun': 0.0,
#   'weekend': 0.0,
#   'operater': 0.0,
#   '911': 0.0,
#   'workin': 0.0,
#   'emergency': 0.0,
#   'land': 0.0,
#   'redhead': 0.0,
#   'mercy': 0.0,
#   'swingin': 0.0,
#   'sign': 0.0,
#   'neon': 0.0,
#   'country': 0.0,
#   'thirstin': 0.0,
#   'intensive': 0.0,
#   'dirt': 0.0,
#   'afraid': 0.0,
#   'honkytonk': 0.0,
#   'piece': 0.0,
#   'thinkin': 0.0,
#   'brunette': 0.0,
#   'hurtin': 0.0,
#   'anywhere': 0.0,
#   'mapped': 0.0,
#   'nursin': 0.0,
#   'tried': 0.0,
#   'thumpin': 0.0,
#   'jumpin': 0.0,
#   'hopin': 0.0,
#   'broken': 0.0,
#   'little': 0.0,
#   'promised': 0.0,
#   'band': 0.0,
#   'sound': 0.0,
#   'karaoke': 0.0,
#   'blonde': 0.0,
#   'wheres': 0.0,
#   'angel': 0.0,
#   'care': 0.0,
#   'operator': 0.0,
#   'n': 0.0,
#   'later': 0.0,
#   'week': 0.0,
#   'aint': 0.0,
#   'help': 0.0,
#   'remedy': 0.0,
#   'phone': 0.0,
#   'siri': 0.0,
#   'hang': 0.0,
#   'glowin': 0.0,
#   'answer': 0.0,
#   'jukejoint': 0.0,
#   'people': 0.0,
#   'moral': 0.0,
#   'live': 0.0,
#   'calculated': 0.0,
#   'endorsin': 0.0,
#   'skin': 0.0,
#   'small': 0.0,
#   'recognize': 0.0,
#   'covered': 0.0,
#   'entitled': 0.0,
#   'dealin': 0.0,
#   'stay': 0.0,
#   'nobody': 0.0,
#   'winnin': 0.0,
#   'shit': 0.0,
#   'ya': 0.0,
#   'bad': 0.0,
#   'ego': 0.0,
#   'promises': 0.0,
#   'fuck': 0.0,
#   'kinda': 0.0,
#   'buildin': 0.0,
#   'feel': 0.0,
#   'motherfucker': 0.0,
#   'tryna': 0.0,
#   'realest': 0.0,
#   'did': 0.0,
#   'days': 0.0,
#   'breathin': 0.0,
#   'bring': 0.0,
#   'closer': 0.0,
#   'nothin': 0.0,
#   'prayin': 0.0,
#   'false': 0.0,
#   'talkin': 0.0,
#   'involved': 0.0,
#   'stars': 0.0,
#   'expectations': 0.0,
#   'credit': 0.0,
#   'lamar': 0.0,
#   'sza': 0.0,
#   'confidence': 0.0,
#   'percentage': 0.0,
#   'approach': 0.0,
#   'conversation': 0.0,
#   'reason': 0.0,
#   'truth': 0.0,
#   'confrontation': 0.0,
#   'hate': 0.0,
#   'important': 0.0,
#   'thanks': 0.0,
#   'hoped': 0.0,
#   'game': 0.0,
#   'kendrick': 0.0,
#   'wouldnt': 0.0,
#   'rebound': 0.0,
#   'congratulations': 0.0,
#   'might': 0.0,
#   'story': 0.0,
#   'losin': 0.0,
#   'invite': 0.0,
#   'momma': 0.0,
#   'morgue': 0.0,
#   'look': 0.0,
#   'hours': 0.0,
#   'haunt': 0.0,
#   'corrupt': 0.0,
#   'sword': 0.0,
#   'cryin': 0.0,
#   'making': 0.0,
#   'lee': 0.0,
#   'contribution': 0.0,
#   'alone': 0.0,
#   'power': 0.0,
#   'had': 0.0,
#   'nigga': 0.0,
#   'why': 0.0,
#   'castin': 0.0,
#   'carryin': 0.0,
#   'uh': 0.0,
#   'fucked': 0.0,
#   'turned': 0.0,
#   'easy': 0.0,
#   'knowow': 0.0,
#   'views': 0.0,
#   'city': 0.0,
#   'fly': 0.0,
#   'body': 0.0,
#   'travel': 0.0,
#   'doin': 0.0,
#   'beams': 0.0,
#   'ayy': 0.0,
#   'dust': 0.0,
#   'khalid': 0.0,
#   'brother': 0.0,
#   'swae': 0.0,
#   'niggas': 0.0,
#   'most': 0.0,
#   'knowowow': 0.0,
#   'lose': 0.0,
#   'goin': 0.0,
#   'safe': 0.0,
#   'radion': 0.0,
#   'everywhere': 0.0,
#   'somethin': 0.0,
#   'section': 0.0,
#   'vibrant': 0.0,
#   'movin': 0.0,
#   'many': 0.0,
#   'pick': 0.0,
#   'only': 0.0,
#   'roll': 0.0,
#   'finesse': 0.0,
#   'until': 0.0,
#   'ward': 0.0,
#   'rims': 0.0,
#   'tangle': 0.0,
#   'genocide': 0.0,
#   'girls': 0.0,
#   'church': 0.0,
#   'figurines': 0.0,
#   'scarface': 0.0,
#   'other': 0.0,
#   'blakrok': 0.0,
#   'coons': 0.0,
#   'signatures': 0.0,
#   'nothing': 0.0,
#   'friend': 0.0,
#   'drown': 0.0,
#   'antidote': 0.0,
#   'cleaver': 0.0,
#   'rover': 0.0,
#   'roar': 0.0,
#   'bars': 0.0,
#   'blues': 0.0,
#   'size': 0.0,
#   'drawn': 0.0,
#   'dog': 0.0,
#   'crushing': 0.0,
#   'toâ€': 0.0,
#   'half': 0.0,
#   'stack': 0.0,
#   'cyborg': 0.0,
#   'aura': 0.0,
#   'surface': 0.0,
#   'freeze': 0.0,
#   'poison': 0.0,
#   'bend': 0.0,
#   'mouth': 0.0,
#   'jackson': 0.0,
#   'chase': 0.0,
#   'coupe': 0.0,
#   'wide': 0.0,
#   'obscene': 0.0,
#   'flex': 0.0,
#   'spit': 0.0,
#   'slick': 0.0,
#   'die': 0.0,
#   'break': 0.0,
#   'yugen': 0.0,
#   'crimes': 0.0,
#   'sittin': 0.0,
#   'cover': 0.0,
#   'millipede': 0.0,
#   'tend': 0.0,
#   'chords': 0.0,
#   'trapped': 0.0,
#   'butterflies': 0.0,
#   'spitting': 0.0,
#   'trees': 0.0,
#   'shoot': 0.0,
#   'lasers': 0.0,
#   'takes': 0.0,
#   'spinning': 0.0,
#   'benz': 0.0,
#   'submarine': 0.0,
#   'flowers': 0.0,
#   'hirez': 0.0,
#   'mines': 0.0,
#   'staples': 0.0,
#   'own': 0.0,
#   'hurts': 0.0,
#   'ground': 0.0,
#   'seasoned': 0.0,
#   'pity': 0.0,
#   'vince': 0.0,
#   'swimming': 0.0,
#   'gotham': 0.0,
#   'livin': 0.0,
#   'defeat': 0.0,
#   'rhymes': 0.0,
#   'eyes': 0.0,
#   'attack': 0.0,
#   'brain': 0.0,
#   'kathleen': 0.0,
#   'lemons': 0.0,
#   'ball': 0.0,
#   'cab': 0.0,
#   'bleeding': 0.0,
#   'strength': 0.0,
#   'opps': 0.0,
#   'blades': 0.0,
#   'armory': 0.0,
#   'sinister': 0.0,
#   'machine': 0.0,
#   'rubber': 0.0,
#   'streets': 0.0,
#   'behind': 0.0,
#   'getting': 0.0,
#   'belittles': 0.0,
#   'beam': 0.0,
#   '20': 0.0,
#   'side': 0.0,
#   'blame': 0.0,
#   'sin': 0.0,
#   'speed': 0.0,
#   'zone': 0.0,
#   'raw': 0.0,
#   'taxi': 0.0,
#   'committing': 0.0,
#   'clean': 0.0,
#   'millie': 0.0,
#   'alive': 0.0,
#   'turn': 0.0,
#   'colours': 0.0,
#   'keys': 0.0,
#   'worth': 0.0,
#   'bodies': 0.0,
#   'lime': 0.0,
#   'psych': 0.0,
#   'yall': 0.0,
#   'lioness': 0.0,
#   'tendons': 0.0,
#   'subliminal': 0.0,
#   'zoom': 0.0,
#   'weaver': 0.0,
#   'criminal': 0.0,
#   'brothers': 0.0,
#   'thing': 0.0,
#   'bought': 0.0,
#   'thought': 0.0,
#   'verbal': 0.0,
#   'system': 0.0,
#   '”': 0.0,
#   'radar': 0.0,
#   'debt': 0.0,
#   'thatll': 0.0,
#   'judge': 0.0,
#   'check': 0.0,
#   'hey': 0.0,
#   'brown': 0.0,
#   'punch': 0.0,
#   'administer': 0.0,
#   'top': 0.0,
#   'gave': 0.0,
#   'watch': 0.0,
#   'stand': 0.0,
#   'gettin': 0.0,
#   'any': 0.0,
#   'dead': 0.0,
#   'rhyme': 0.0,
#   'censored': 0.0,
#   'perimeter': 0.0,
#   'stop': 0.0,
#   'sometimes': 0.0,
#   'offends': 0.0,
#   'sacrifice': 0.0,
#   'margin': 0.0,
#   'satisfied': 0.0,
#   'smith': 0.0,
#   'triggering': 0.0,
#   'opinion': 0.0,
#   'shame': 0.0,
#   'part': 0.0,
#   'fears': 0.0,
#   'feels': 0.0,
#   'ohh': 0.0,
#   'voicing': 0.0,
#   'sorry': 0.0,
#   'scared': 0.0,
#   'change': 0.0,
#   'subject': 0.0,
#   'wins': 0.0,
#   'depending': 0.0,
#   'tryin': 0.0,
#   'real': 0.0,
#   'course': 0.0,
#   'letter': 0.0,
#   'loss': 0.0,
#   'anymore': 0.0,
#   'indifferent': 0.0,
#   'yah': 0.0,
#   'homecoming': 0.0,
#   'too': 0.0,
#   'jorja': 0.0,
#   'somebody': 0.0,
#   'meant': 0.0,
#   'asked': 0.0,
#   'please': 0.0,
#   'partner': 0.0,
#   'jamaica': 0.0,
#   'pack': 0.0,
#   'lows': 0.0,
#   'thirty': 0.0,
#   'reside': 0.0,
#   'hittas': 0.0,
#   'ship': 0.0,
#   'huh': 0.0,
#   'eyy': 0.0,
#   'patois': 0.0,
#   'smoke': 0.0,
#   'squad': 0.0,
#   'princeturnedpope': 0.0,
#   'everlasting': 0.0,
#   'juggin': 0.0,
#   'hollow': 0.0,
#   'mopped': 0.0,
#   'aftermath': 0.0,
#   'games': 0.0,
#   'write': 0.0,
#   'passengers': 0.0,
#   'nerve': 0.0,
#   'lawless': 0.0,
#   'remote': 0.0,
#   'survive': 0.0,
#   'gas': 0.0,
#   'mayhem': 0.0,
#   'blah': 0.0,
#   'double': 0.0,
#   'thank': 0.0,
#   'lox': 0.0,
#   'cleaning': 0.0,
#   'closed': 0.0,
#   'whats': 0.0,
#   'scope': 0.0,
#   'first': 0.0,
#   'lights': 0.0,
#   'organized': 0.0,
#   'general': 0.0,
#   'planes': 0.0,
#   'everybody': 0.0,
#   'anderson': 0.0,
#   'kings': 0.0,
#   'claimed': 0.0,
#   'caution': 0.0,
#   'blood': 0.0,
#   'devoted': 0.0,
#   'bypass': 0.0,
#   'dough': 0.0,
#   'war': 0.0,
#   'russians': 0.0,
#   'del': 0.0,
#   'acquitted': 0.0,
#   'agua': 0.0,
#   'absoul': 0.0,
#   'dark': 0.0,
#   'dirty': 0.0,
#   'low': 0.0,
#   'hot': 0.0,
#   'mando': 0.0,
#   'buried': 0.0,
#   'stealing': 0.0,
#   'depart': 0.0,
#   ...},
#  {'sea': 0.0,
#   'valentines': 0.0,
#   'lent': 0.0,
#   'cup': 0.0,
#   'hands': 0.0,
#   'scenes': 0.0,
#   'dreams': 0.0,
#   'girl': 1.2039728043259361,
#   'passage': 0.0,
#   '9': 0.0,
#   'theres': 1.0498221244986776,
#   'thunder': 0.0,
#   'signed': 0.0,
#   'occurred': 0.0,
#   'ride': 0.0,
#   'ore': 0.0,
#   'heaven': 0.0,
#   'was': 0.0,
#   'queens': 0.0,
#   'walked': 0.0,
#   'on': 0.05129329438755048,
#   'know': 0.3566749439387324,
#   'my': 2.584697496554726,
#   'or': 0.0,
#   'his': 0.0,
#   'sad': 0.0,
#   'took': 0.0,
#   'rodeo': 0.0,
#   'together': 0.0,
#   'bed': 0.0,
#   'born': 0.0,
#   'so': 0.0,
#   'she': 0.0,
#   'made': 0.0,
#   'from': 0.0,
#   'runnin': 0.0,
#   'green': 0.0,
#   'raised': 0.0,
#   'ventura': 0.0,
#   'mind': 0.0,
#   'fiery': 0.0,
#   'a': 0.3250378589955499,
#   'be': 1.292348748277363,
#   'rode': 0.0,
#   'forget': 0.0,
#   'and': 0.41034635510040385,
#   'hold': 0.0,
#   'to': 0.10258658877510096,
#   'song': 0.0,
#   'passed': 0.0,
#   'me': 0.22314355131420976,
#   'maple': 0.0,
#   'they': 0.5978370007556204,
#   'herb': 0.0,
#   'enshrined': 0.0,
#   'fourteen': 0.0,
#   'through': 0.0,
#   '8teen': 0.0,
#   'you': 0.0,
#   'moves': 0.0,
#   'beneath': 0.0,
#   'night': 0.0,
#   'strings': 0.0,
#   'words': 0.0,
#   'beside': 0.0,
#   'such': 0.0,
#   'that': 1.1376325064844246,
#   'luck': 0.0,
#   'where': 1.6094379124341003,
#   'an': 0.0,
#   'pristine': 0.0,
#   'will': 3.7942399697717626,
#   'silver': 0.0,
#   'blessing': 0.0,
#   'said': 0.0,
#   'day': 0.0,
#   'gods': 0.0,
#   'how': 1.1956740015112408,
#   'out': 0.3566749439387324,
#   'rolled': 0.0,
#   'the': 1.6251892949777493,
#   'could': 0.0,
#   'we': 0.0,
#   'every': 0.0,
#   'when': 0.7133498878774648,
#   'cross': 0.0,
#   'new': 0.0,
#   'teach': 0.0,
#   'now': 0.0,
#   'wild': 0.0,
#   'their': 0.0,
#   'everyone': 0.0,
#   'plate': 0.0,
#   'he': 0.0,
#   'gates': 0.0,
#   'jc': 0.0,
#   'there': 0.0,
#   'adds': 0.0,
#   'water': 0.0,
#   'all': 0.8925742052568391,
#   'kept': 0.0,
#   'borderline': 0.0,
#   'jesus': 0.0,
#   'free': 0.0,
#   'big': 0.0,
#   'red': 0.0,
#   'her': 0.0,
#   'state': 0.0,
#   'as': 4.8158912173037445,
#   'gift': 0.0,
#   'japan': 0.0,
#   'uncle': 0.0,
#   'pearly': 0.0,
#   'nimbus': 0.0,
#   'heard': 0.0,
#   'time': 0.0,
#   'trinity': 0.0,
#   'letters': 0.0,
#   'for': 1.292348748277363,
#   'underlined': 0.0,
#   'frozen': 0.0,
#   'about': 0.0,
#   'highway': 0.0,
#   'in': 0.10536051565782635,
#   'bullet': 0.0,
#   'oh': 0.0,
#   'call': 0.0,
#   'leaf': 0.0,
#   'up': 0.0,
#   'hummed': 0.0,
#   'of': 0.0,
#   'forever': 0.0,
#   'miracle': 0.0,
#   'vincent': 0.0,
#   'sunshine': 0.0,
#   'spent': 0.0,
#   'ear': 0.0,
#   'it': 1.3388613078852587,
#   'six': 0.0,
#   'runneth': 0.0,
#   'team': 0.0,
#   'never': 1.8325814637483102,
#   'each': 0.0,
#   'though': 0.0,
#   'working': 2.995732273553991,
#   'aching': 2.995732273553991,
#   'are': 1.0498221244986776,
#   'doesnt': 2.302585092994046,
#   'over': 2.772588722239781,
#   'lane': 2.995732273553991,
#   'wanting': 2.995732273553991,
#   'guess': 2.995732273553991,
#   'friends': 8.047189562170502,
#   'beer': 2.995732273553991,
#   'back': 1.2039728043259361,
#   'talking': 2.995732273553991,
#   'shes': 1.8971199848858813,
#   'starts': 4.605170185988092,
#   'should': 3.7942399697717626,
#   'cowboys': 14.978661367769954,
#   'head': 1.6094379124341003,
#   'soon': 5.991464547107982,
#   'wait': 1.8971199848858813,
#   'work': 2.302585092994046,
#   'again': 4.828313737302301,
#   'cause': 2.772588722239781,
#   'begins': 6.907755278982138,
#   'jack': 2.302585092994046,
#   'ends': 6.907755278982138,
#   'leave': 2.302585092994046,
#   'going': 1.6094379124341003,
#   'home': 1.8971199848858813,
#   'were': 1.3862943611198906,
#   'fun': 5.991464547107982,
#   'threatening': 2.995732273553991,
#   'late': 5.991464547107982,
#   'wearing': 2.995732273553991,
#   'have': 0.7985076962177716,
#   'busting': 2.995732273553991,
#   'sleep': 2.302585092994046,
#   'morning': 2.995732273553991,
#   'party': 5.691359954657644,
#   'with': 1.3862943611198906,
#   'theyre': 1.6094379124341003,
#   'who': 0.7985076962177716,
#   'just': 0.8615658321849087,
#   'yeah': 3.1494663734960326,
#   'shirt': 2.995732273553991,
#   'goes': 5.991464547107982,
#   'nightstand': 2.995732273553991,
#   'its': 2.1539145804622715,
#   'yes': 2.302585092994046,
#   'road': 1.8971199848858813,
#   'ive': 1.3862943611198906,
#   'this': 0.43078291609245434,
#   'breakfast': 2.995732273553991,
#   'kitchen': 2.995732273553991,
#   'keep': 1.3862943611198906,
#   'say': 1.0498221244986776,
#   'is': 0.22314355131420976,
#   'been': 3.1494663734960326,
#   'thats': 4.1588830833596715,
#   'im': 0.8615658321849087,
#   'foreman': 2.995732273553991,
#   'two': 1.3862943611198906,
#   'way': 4.8158912173037445,
#   'buddies': 5.991464547107982,
#   'crime': 0.0,
#   'open': 0.0,
#   'last': 0.0,
#   'feeling': 0.0,
#   'swing': 0.0,
#   'right': 0.0,
#   'knocks': 0.0,
#   'get': 0.0,
#   'need': 0.0,
#   'four': 0.0,
#   'car': 0.0,
#   'worked': 0.0,
#   'down': 0.0,
#   'turns': 0.0,
#   'something': 0.0,
#   'sees': 0.0,
#   'says': 0.0,
#   'would': 0.0,
#   'face': 0.0,
#   'beach': 0.0,
#   'em': 0.0,
#   'gets': 0.0,
#   'problem': 0.0,
#   'thieving': 0.0,
#   'dessert': 0.0,
#   'monday': 0.0,
#   'ill': 0.0,
#   'knows': 0.0,
#   'dinner': 0.0,
#   'gone': 0.0,
#   'heading': 0.0,
#   'pickup': 0.0,
#   'perfect': 0.0,
#   'plan': 0.0,
#   'complete': 0.0,
#   'somethings': 0.0,
#   'gifted': 0.0,
#   'amen': 0.0,
#   'switch': 0.0,
#   'score': 0.0,
#   'youre': 0.0,
#   'lets': 0.0,
#   'evening': 0.0,
#   'set': 0.0,
#   'flash': 0.0,
#   'must': 0.0,
#   'light': 0.0,
#   'afternoon': 0.0,
#   'like': 0.0,
#   'happened': 0.0,
#   'clydes': 0.0,
#   'seen': 0.0,
#   'him': 0.0,
#   'once': 0.0,
#   'petty': 0.0,
#   'thousand': 0.0,
#   'clyde': 0.0,
#   'standing': 0.0,
#   'times': 0.0,
#   'swaps': 0.0,
#   'hit': 0.0,
#   'more': 0.0,
#   'let': 0.0,
#   'floor': 0.0,
#   'sleight': 0.0,
#   'grabs': 0.0,
#   'end': 0.0,
#   'seems': 0.0,
#   'bout': 0.0,
#   'not': 0.0,
#   'if': 0.0,
#   'sands': 0.0,
#   'run': 0.0,
#   'find': 0.0,
#   'hand': 0.0,
#   'but': 0.0,
#   'jump': 0.0,
#   'armored': 0.0,
#   'before': 0.0,
#   'stopping': 0.0,
#   'dealer': 0.0,
#   'away': 0.0,
#   'joann': 0.0,
#   'guards': 0.0,
#   'window': 0.0,
#   'na': 0.0,
#   'happy': 0.0,
#   'west': 0.0,
#   'conniving': 0.0,
#   'hes': 0.0,
#   'at': 0.0,
#   'hustle': 0.0,
#   'asks': 0.0,
#   'man': 0.0,
#   'bang': 0.0,
#   'someday': 0.0,
#   'hiding': 0.0,
#   'see': 0.0,
#   'good': 0.0,
#   'door': 0.0,
#   'guard': 0.0,
#   'shows': 0.0,
#   'money': 0.0,
#   'cash': 0.0,
#   'desert': 0.0,
#   'master': 0.0,
#   'house': 0.0,
#   'meet': 0.0,
#   'friday': 0.0,
#   'bags': 0.0,
#   'bangs': 0.0,
#   'play': 0.0,
#   'doors': 0.0,
#   'both': 0.0,
#   'ways': 0.0,
#   'gon': 0.0,
#   'fire': 0.0,
#   'rest': 0.0,
#   'what': 0.0,
#   'after': 0.0,
#   'driving': 0.0,
#   'talk': 0.0,
#   'hell': 0.0,
#   'fought': 0.0,
#   'lady': 0.0,
#   'high': 0.0,
#   'better': 0.0,
#   'crazy': 0.0,
#   'hope': 0.0,
#   'burning': 0.0,
#   'whiskey': 0.0,
#   'wine': 0.0,
#   'rejoin': 0.0,
#   'polite': 0.0,
#   'probably': 0.0,
#   'damn': 0.0,
#   'desire': 0.0,
#   'walking': 0.0,
#   'handsome': 0.0,
#   'no': 0.0,
#   'try': 0.0,
#   'always': 0.0,
#   'mans': 0.0,
#   'nice': 0.0,
#   'hoping': 0.0,
#   'show': 0.0,
#   'listens': 0.0,
#   'best': 0.0,
#   'dont': 0.0,
#   'refined': 0.0,
#   'pretty': 0.0,
#   'sure': 0.0,
#   'than': 0.0,
#   'miss': 0.0,
#   'loved': 0.0,
#   'knowing': 0.0,
#   'missing': 0.0,
#   'patient': 0.0,
#   'romantic': 0.0,
#   'same': 0.0,
#   'i': 0.0,
#   'showing': 0.0,
#   'move': 0.0,
#   'pass': 0.0,
#   'one': 0.0,
#   'ones': 0.0,
#   'nowhere': 0.0,
#   'hide': 0.0,
#   'unleash': 0.0,
#   'chosen': 0.0,
#   'storm': 0.0,
#   'drumming': 0.0,
#   'life': 0.0,
#   'pissed': 0.0,
#   'give': 0.0,
#   'waited': 0.0,
#   'young': 0.0,
#   'makin': 0.0,
#   'prove': 0.0,
#   'different': 0.0,
#   'them': 0.0,
#   'running': 0.0,
#   'some': 0.0,
#   'coming': 0.0,
#   'pure': 0.0,
#   'hear': 0.0,
#   'ever': 0.0,
#   'adrenaline': 0.0,
#   'ready': 0.0,
#   'chance': 0.0,
#   'multitudes': 0.0,
#   'whole': 0.0,
#   'kill': 0.0,
#   'dance': 0.0,
#   'dial': 0.0,
#   'want': 0.0,
#   'fates': 0.0,
#   'god': 0.0,
#   'long': 0.0,
#   'kickin': 0.0,
#   'forgotten': 0.0,
#   'got': 0.0,
#   'youve': 0.0,
#   'your': 0.0,
#   'inside': 0.0,
#   'drummer': 0.0,
#   'world': 0.0,
#   'byway': 0.0,
#   'off': 0.0,
#   'has': 0.0,
#   'beast': 0.0,
#   'stretch': 0.0,
#   'standin': 0.0,
#   'done': 0.0,
#   'lift': 0.0,
#   'knees': 0.0,
#   'second': 0.0,
#   'come': 0.0,
#   'desperate': 0.0,
#   'really': 0.0,
#   'true': 0.0,
#   'loves': 0.0,
#   'color': 0.0,
#   'changed': 0.0,
#   'isnt': 0.0,
#   'hed': 0.0,
#   'truly': 0.0,
#   'whoever': 0.0,
#   'prayer': 0.0,
#   'take': 0.0,
#   'shoulder': 0.0,
#   'lanes': 0.0,
#   'sitting': 0.0,
#   'us': 0.0,
#   'guys': 0.0,
#   'hers': 0.0,
#   'realize': 0.0,
#   'knew': 0.0,
#   'alright': 0.0,
#   'today': 0.0,
#   'fast': 0.0,
#   'can': 0.0,
#   'hard': 0.0,
#   'oclock': 0.0,
#   'nothings': 0.0,
#   'worse': 0.0,
#   'everything': 0.0,
#   'simply': 0.0,
#   'youd': 0.0,
#   'looks': 0.0,
#   'tonight': 0.0,
#   'crawl': 0.0,
#   'traffic': 0.0,
#   'finally': 0.0,
#   'five': 0.0,
#   'then': 0.0,
#   'falls': 0.0,
#   'wreck': 0.0,
#   'close': 0.0,
#   'much': 0.0,
#   'do': 0.0,
#   'tell': 0.0,
#   'crash': 0.0,
#   'changes': 0.0,
#   'model': 0.0,
#   'dying': 0.0,
#   'whoa': 0.0,
#   'lay': 0.0,
#   'save': 0.0,
#   'name': 0.0,
#   'explain': 0.0,
#   'heart': 0.0,
#   'love': 0.0,
#   'counting': 0.0,
#   'quite': 0.0,
#   'smile': 0.0,
#   'circumstance': 0.0,
#   'baby': 0.0,
#   'kind': 0.0,
#   'may': 0.0,
#   'hazy': 0.0,
#   'thinking': 0.0,
#   'known': 0.0,
#   'style': 0.0,
#   'pray': 0.0,
#   'cant': 0.0,
#   'black': 0.0,
#   'drive': 0.0,
#   'moving': 0.0,
#   'blind': 0.0,
#   'blue': 0.0,
#   'romance': 0.0,
#   'swore': 0.0,
#   'go': 0.0,
#   'victim': 0.0,
#   'brand': 0.0,
#   'comes': 0.0,
#   'trance': 0.0,
#   'felt': 0.0,
#   'shake': 0.0,
#   'youll': 0.0,
#   'fool': 0.0,
#   'things': 0.0,
#   'stubborn': 0.0,
#   'rules': 0.0,
#   'make': 0.0,
#   'pride': 0.0,
#   'anything': 0.0,
#   'trying': 0.0,
#   'settle': 0.0,
#   'ask': 0.0,
#   'push': 0.0,
#   'walls': 0.0,
#   'wont': 0.0,
#   'fall': 0.0,
#   'wrong': 0.0,
#   'freedom': 0.0,
#   'beg': 0.0,
#   'am': 0.0,
#   'figure': 0.0,
#   'maybe': 0.0,
#   'stick': 0.0,
#   'repeat': 0.0,
#   'shell': 0.0,
#   'around': 0.0,
#   'building': 0.0,
#   'space': 0.0,
#   'id': 0.0,
#   'start': 0.0,
#   'spending': 0.0,
#   'put': 0.0,
#   'another': 0.0,
#   'onto': 0.0,
#   'ta': 0.0,
#   'siena': 0.0,
#   'wherever': 0.0,
#   'cabanas': 0.0,
#   'means': 0.0,
#   'vienna': 0.0,
#   'south': 0.0,
#   'well': 0.0,
#   'sundown': 0.0,
#   'needs': 0.0,
#   'bet': 0.0,
#   'champaignurbana': 0.0,
#   'sweet': 0.0,
#   'even': 0.0,
#   'atlanta': 0.0,
#   'indiana': 0.0,
#   'wake': 0.0,
#   'still': 0.0,
#   'loving': 0.0,
#   'swear': 0.0,
#   'western': 0.0,
#   'havana': 0.0,
#   'track': 0.0,
#   'lord': 0.0,
#   'unwind': 0.0,
#   'montana': 0.0,
#   'chantin': 0.0,
#   'alabama': 0.0,
#   'laughing': 0.0,
#   'singing': 0.0,
#   'enough': 0.0,
#   'somewhere': 0.0,
#   'savannah': 0.0,
#   'rocking': 0.0,
#   'guyana': 0.0,
#   'our': 0.0,
#   'here': 0.0,
#   'louisiana': 0.0,
#   'rockin': 0.0,
#   'pajamas': 0.0,
#   'wan': 0.0,
#   'rollin': 0.0,
#   'muncie': 0.0,
#   'snakin': 0.0,
#   'dancing': 0.0,
#   'sun': 0.0,
#   'weekend': 0.0,
#   'operater': 0.0,
#   '911': 0.0,
#   'workin': 0.0,
#   'emergency': 0.0,
#   'land': 0.0,
#   'redhead': 0.0,
#   'mercy': 0.0,
#   'swingin': 0.0,
#   'sign': 0.0,
#   'neon': 0.0,
#   'country': 0.0,
#   'thirstin': 0.0,
#   'intensive': 0.0,
#   'dirt': 0.0,
#   'afraid': 0.0,
#   'honkytonk': 0.0,
#   'piece': 0.0,
#   'thinkin': 0.0,
#   'brunette': 0.0,
#   'hurtin': 0.0,
#   'anywhere': 0.0,
#   'mapped': 0.0,
#   'nursin': 0.0,
#   'tried': 0.0,
#   'thumpin': 0.0,
#   'jumpin': 0.0,
#   'hopin': 0.0,
#   'broken': 0.0,
#   'little': 0.0,
#   'promised': 0.0,
#   'band': 0.0,
#   'sound': 0.0,
#   'karaoke': 0.0,
#   'blonde': 0.0,
#   'wheres': 0.0,
#   'angel': 0.0,
#   'care': 0.0,
#   'operator': 0.0,
#   'n': 0.0,
#   'later': 0.0,
#   'week': 0.0,
#   'aint': 0.0,
#   'help': 0.0,
#   'remedy': 0.0,
#   'phone': 0.0,
#   'siri': 0.0,
#   'hang': 0.0,
#   'glowin': 0.0,
#   'answer': 0.0,
#   'jukejoint': 0.0,
#   'people': 0.0,
#   'moral': 0.0,
#   'live': 0.0,
#   'calculated': 0.0,
#   'endorsin': 0.0,
#   'skin': 0.0,
#   'small': 0.0,
#   'recognize': 0.0,
#   'covered': 0.0,
#   'entitled': 0.0,
#   'dealin': 0.0,
#   'stay': 0.0,
#   'nobody': 0.0,
#   'winnin': 0.0,
#   'shit': 0.0,
#   'ya': 0.0,
#   'bad': 0.0,
#   'ego': 0.0,
#   'promises': 0.0,
#   'fuck': 0.0,
#   'kinda': 0.0,
#   'buildin': 0.0,
#   'feel': 0.0,
#   'motherfucker': 0.0,
#   'tryna': 0.0,
#   'realest': 0.0,
#   'did': 0.0,
#   'days': 0.0,
#   'breathin': 0.0,
#   'bring': 0.0,
#   'closer': 0.0,
#   'nothin': 0.0,
#   'prayin': 0.0,
#   'false': 0.0,
#   'talkin': 0.0,
#   'involved': 0.0,
#   'stars': 0.0,
#   'expectations': 0.0,
#   'credit': 0.0,
#   'lamar': 0.0,
#   'sza': 0.0,
#   'confidence': 0.0,
#   'percentage': 0.0,
#   'approach': 0.0,
#   'conversation': 0.0,
#   'reason': 0.0,
#   'truth': 0.0,
#   'confrontation': 0.0,
#   'hate': 0.0,
#   'important': 0.0,
#   'thanks': 0.0,
#   'hoped': 0.0,
#   'game': 0.0,
#   'kendrick': 0.0,
#   'wouldnt': 0.0,
#   'rebound': 0.0,
#   'congratulations': 0.0,
#   'might': 0.0,
#   'story': 0.0,
#   'losin': 0.0,
#   'invite': 0.0,
#   'momma': 0.0,
#   'morgue': 0.0,
#   'look': 0.0,
#   'hours': 0.0,
#   'haunt': 0.0,
#   'corrupt': 0.0,
#   'sword': 0.0,
#   'cryin': 0.0,
#   'making': 0.0,
#   'lee': 0.0,
#   'contribution': 0.0,
#   'alone': 0.0,
#   'power': 0.0,
#   'had': 0.0,
#   'nigga': 0.0,
#   'why': 0.0,
#   'castin': 0.0,
#   'carryin': 0.0,
#   'uh': 0.0,
#   'fucked': 0.0,
#   'turned': 0.0,
#   'easy': 0.0,
#   'knowow': 0.0,
#   'views': 0.0,
#   'city': 0.0,
#   'fly': 0.0,
#   'body': 0.0,
#   'travel': 0.0,
#   'doin': 0.0,
#   'beams': 0.0,
#   'ayy': 0.0,
#   'dust': 0.0,
#   'khalid': 0.0,
#   'brother': 0.0,
#   'swae': 0.0,
#   'niggas': 0.0,
#   'most': 0.0,
#   'knowowow': 0.0,
#   'lose': 0.0,
#   'goin': 0.0,
#   'safe': 0.0,
#   'radion': 0.0,
#   'everywhere': 0.0,
#   'somethin': 0.0,
#   'section': 0.0,
#   'vibrant': 0.0,
#   'movin': 0.0,
#   'many': 0.0,
#   'pick': 0.0,
#   'only': 0.0,
#   'roll': 0.0,
#   'finesse': 0.0,
#   'until': 0.0,
#   'ward': 0.0,
#   'rims': 0.0,
#   'tangle': 0.0,
#   'genocide': 0.0,
#   'girls': 0.0,
#   'church': 0.0,
#   'figurines': 0.0,
#   'scarface': 0.0,
#   'other': 0.0,
#   'blakrok': 0.0,
#   'coons': 0.0,
#   'signatures': 0.0,
#   'nothing': 0.0,
#   'friend': 0.0,
#   'drown': 0.0,
#   'antidote': 0.0,
#   'cleaver': 0.0,
#   'rover': 0.0,
#   'roar': 0.0,
#   'bars': 0.0,
#   'blues': 0.0,
#   'size': 0.0,
#   'drawn': 0.0,
#   'dog': 0.0,
#   'crushing': 0.0,
#   'toâ€': 0.0,
#   'half': 0.0,
#   'stack': 0.0,
#   'cyborg': 0.0,
#   'aura': 0.0,
#   'surface': 0.0,
#   'freeze': 0.0,
#   'poison': 0.0,
#   'bend': 0.0,
#   'mouth': 0.0,
#   'jackson': 0.0,
#   'chase': 0.0,
#   'coupe': 0.0,
#   'wide': 0.0,
#   'obscene': 0.0,
#   'flex': 0.0,
#   'spit': 0.0,
#   'slick': 0.0,
#   'die': 0.0,
#   'break': 0.0,
#   'yugen': 0.0,
#   'crimes': 0.0,
#   'sittin': 0.0,
#   'cover': 0.0,
#   'millipede': 0.0,
#   'tend': 0.0,
#   'chords': 0.0,
#   'trapped': 0.0,
#   'butterflies': 0.0,
#   'spitting': 0.0,
#   'trees': 0.0,
#   'shoot': 0.0,
#   'lasers': 0.0,
#   'takes': 0.0,
#   'spinning': 0.0,
#   'benz': 0.0,
#   'submarine': 0.0,
#   'flowers': 0.0,
#   'hirez': 0.0,
#   'mines': 0.0,
#   'staples': 0.0,
#   'own': 0.0,
#   'hurts': 0.0,
#   'ground': 0.0,
#   'seasoned': 0.0,
#   'pity': 0.0,
#   'vince': 0.0,
#   'swimming': 0.0,
#   'gotham': 0.0,
#   'livin': 0.0,
#   'defeat': 0.0,
#   'rhymes': 0.0,
#   'eyes': 0.0,
#   'attack': 0.0,
#   'brain': 0.0,
#   'kathleen': 0.0,
#   'lemons': 0.0,
#   'ball': 0.0,
#   'cab': 0.0,
#   'bleeding': 0.0,
#   'strength': 0.0,
#   'opps': 0.0,
#   'blades': 0.0,
#   'armory': 0.0,
#   'sinister': 0.0,
#   'machine': 0.0,
#   'rubber': 0.0,
#   'streets': 0.0,
#   'behind': 0.0,
#   'getting': 0.0,
#   'belittles': 0.0,
#   'beam': 0.0,
#   '20': 0.0,
#   'side': 0.0,
#   'blame': 0.0,
#   'sin': 0.0,
#   'speed': 0.0,
#   'zone': 0.0,
#   'raw': 0.0,
#   'taxi': 0.0,
#   'committing': 0.0,
#   'clean': 0.0,
#   'millie': 0.0,
#   'alive': 0.0,
#   'turn': 0.0,
#   'colours': 0.0,
#   'keys': 0.0,
#   'worth': 0.0,
#   'bodies': 0.0,
#   'lime': 0.0,
#   'psych': 0.0,
#   'yall': 0.0,
#   'lioness': 0.0,
#   'tendons': 0.0,
#   'subliminal': 0.0,
#   'zoom': 0.0,
#   'weaver': 0.0,
#   'criminal': 0.0,
#   'brothers': 0.0,
#   'thing': 0.0,
#   'bought': 0.0,
#   'thought': 0.0,
#   'verbal': 0.0,
#   'system': 0.0,
#   '”': 0.0,
#   'radar': 0.0,
#   'debt': 0.0,
#   'thatll': 0.0,
#   'judge': 0.0,
#   'check': 0.0,
#   'hey': 0.0,
#   'brown': 0.0,
#   'punch': 0.0,
#   'administer': 0.0,
#   'top': 0.0,
#   'gave': 0.0,
#   'watch': 0.0,
#   'stand': 0.0,
#   'gettin': 0.0,
#   'any': 0.0,
#   'dead': 0.0,
#   'rhyme': 0.0,
#   'censored': 0.0,
#   'perimeter': 0.0,
#   'stop': 0.0,
#   'sometimes': 0.0,
#   'offends': 0.0,
#   'sacrifice': 0.0,
#   'margin': 0.0,
#   'satisfied': 0.0,
#   'smith': 0.0,
#   'triggering': 0.0,
#   'opinion': 0.0,
#   'shame': 0.0,
#   'part': 0.0,
#   'fears': 0.0,
#   'feels': 0.0,
#   'ohh': 0.0,
#   'voicing': 0.0,
#   'sorry': 0.0,
#   'scared': 0.0,
#   'change': 0.0,
#   'subject': 0.0,
#   'wins': 0.0,
#   'depending': 0.0,
#   'tryin': 0.0,
#   'real': 0.0,
#   'course': 0.0,
#   'letter': 0.0,
#   'loss': 0.0,
#   'anymore': 0.0,
#   'indifferent': 0.0,
#   'yah': 0.0,
#   'homecoming': 0.0,
#   'too': 0.0,
#   'jorja': 0.0,
#   'somebody': 0.0,
#   'meant': 0.0,
#   'asked': 0.0,
#   'please': 0.0,
#   'partner': 0.0,
#   'jamaica': 0.0,
#   'pack': 0.0,
#   'lows': 0.0,
#   'thirty': 0.0,
#   'reside': 0.0,
#   'hittas': 0.0,
#   'ship': 0.0,
#   'huh': 0.0,
#   'eyy': 0.0,
#   'patois': 0.0,
#   'smoke': 0.0,
#   'squad': 0.0,
#   'princeturnedpope': 0.0,
#   'everlasting': 0.0,
#   'juggin': 0.0,
#   'hollow': 0.0,
#   'mopped': 0.0,
#   'aftermath': 0.0,
#   'games': 0.0,
#   'write': 0.0,
#   'passengers': 0.0,
#   'nerve': 0.0,
#   'lawless': 0.0,
#   'remote': 0.0,
#   'survive': 0.0,
#   'gas': 0.0,
#   'mayhem': 0.0,
#   'blah': 0.0,
#   'double': 0.0,
#   'thank': 0.0,
#   'lox': 0.0,
#   'cleaning': 0.0,
#   'closed': 0.0,
#   'whats': 0.0,
#   'scope': 0.0,
#   'first': 0.0,
#   'lights': 0.0,
#   'organized': 0.0,
#   'general': 0.0,
#   'planes': 0.0,
#   'everybody': 0.0,
#   'anderson': 0.0,
#   'kings': 0.0,
#   'claimed': 0.0,
#   'caution': 0.0,
#   'blood': 0.0,
#   'devoted': 0.0,
#   'bypass': 0.0,
#   'dough': 0.0,
#   'war': 0.0,
#   'russians': 0.0,
#   'del': 0.0,
#   'acquitted': 0.0,
#   'agua': 0.0,
#   'absoul': 0.0,
#   'dark': 0.0,
#   'dirty': 0.0,
#   'low': 0.0,
#   'hot': 0.0,
#   'mando': 0.0,
#   'buried': 0.0,
#   'stealing': 0.0,
#   'depart': 0.0,
#   ...},
#  {'sea': 0.0,
#   'valentines': 0.0,
#   'lent': 0.0,
#   'cup': 0.0,
#   'hands': 0.0,
#   'scenes': 0.0,
#   'dreams': 1.8971199848858813,
#   'girl': 0.0,
#   'passage': 0.0,
#   '9': 0.0,
#   'theres': 1.0498221244986776,
#   'thunder': 0.0,
#   'signed': 0.0,
#   'occurred': 0.0,
#   'ride': 0.0,
#   'ore': 0.0,
#   'heaven': 0.0,
#   'was': 2.772588722239781,
#   'queens': 0.0,
#   'walked': 0.0,
#   'on': 0.10258658877510096,
#   'know': 0.0,
#   'my': 0.0,
#   'or': 0.0,
#   'his': 0.0,
#   'sad': 0.0,
#   'took': 0.0,
#   'rodeo': 0.0,
#   'together': 0.0,
#   'bed': 0.0,
#   'born': 0.0,
#   'so': 0.7985076962177716,
#   'she': 11.090354888959125,
#   'made': 0.0,
#   'from': 0.6931471805599453,
#   'runnin': 0.0,
#   'green': 0.0,
#   'raised': 0.0,
#   'ventura': 0.0,
#   'mind': 0.0,
#   'fiery': 0.0,
#   'a': 0.8125946474888747,
#   'be': 0.0,
#   'rode': 0.0,
#   'forget': 0.0,
#   'and': 0.5642262382630553,
#   'hold': 0.0,
#   'to': 0.3077597663253029,
#   'song': 0.0,
#   'passed': 0.0,
#   'me': 0.0,
#   'maple': 0.0,
#   'they': 2.3913480030224816,
#   'herb': 0.0,
#   'enshrined': 0.0,
#   'fourteen': 0.0,
#   'through': 1.0498221244986776,
#   '8teen': 0.0,
#   'you': 0.05129329438755048,
#   'moves': 0.0,
#   'beneath': 0.0,
#   'night': 0.0,
#   'strings': 0.0,
#   'words': 0.0,
#   'beside': 0.0,
#   'such': 0.0,
#   'that': 0.3250378589955499,
#   'luck': 0.0,
#   'where': 0.0,
#   'an': 0.0,
#   'pristine': 0.0,
#   'will': 0.0,
#   'silver': 0.0,
#   'blessing': 0.0,
#   'said': 0.0,
#   'day': 0.0,
#   'gods': 0.0,
#   'how': 0.5978370007556204,
#   'out': 1.4266997757549296,
#   'rolled': 2.302585092994046,
#   'the': 3.9004543079465988,
#   'could': 0.0,
#   'we': 0.0,
#   'every': 1.3862943611198906,
#   'when': 1.0700248318161971,
#   'cross': 0.0,
#   'new': 0.0,
#   'teach': 0.0,
#   'now': 1.6094379124341003,
#   'wild': 0.0,
#   'their': 7.588479939543525,
#   'everyone': 0.0,
#   'plate': 0.0,
#   'he': 2.772588722239781,
#   'gates': 0.0,
#   'jc': 0.0,
#   'there': 0.0,
#   'adds': 0.0,
#   'water': 0.0,
#   'all': 0.22314355131420976,
#   'kept': 0.0,
#   'borderline': 0.0,
#   'jesus': 0.0,
#   'free': 0.0,
#   'big': 1.3862943611198906,
#   'red': 0.0,
#   'her': 2.4079456086518722,
#   'state': 0.0,
#   'as': 0.0,
#   'gift': 0.0,
#   'japan': 0.0,
#   'uncle': 0.0,
#   'pearly': 0.0,
#   'nimbus': 0.0,
#   'heard': 2.302585092994046,
#   'time': 0.0,
#   'trinity': 0.0,
#   'letters': 0.0,
#   'for': 0.0,
#   'underlined': 0.0,
#   'frozen': 0.0,
#   'about': 0.0,
#   'highway': 0.0,
#   'in': 0.4214420626313054,
#   'bullet': 0.0,
#   'oh': 0.0,
#   'call': 0.0,
#   'leaf': 0.0,
#   'up': 0.3566749439387324,
#   'hummed': 0.0,
#   'of': 1.7260924347106852,
#   'forever': 0.0,
#   'miracle': 0.0,
#   'vincent': 0.0,
#   'sunshine': 0.0,
#   'spent': 0.0,
#   'ear': 0.0,
#   'it': 0.6694306539426294,
#   'six': 0.0,
#   'runneth': 0.0,
#   'team': 0.0,
#   'never': 1.8325814637483102,
#   'each': 0.0,
#   'though': 0.0,
#   'working': 0.0,
#   'aching': 0.0,
#   'are': 0.0,
#   'doesnt': 0.0,
#   'over': 0.0,
#   'lane': 0.0,
#   'wanting': 0.0,
#   'guess': 0.0,
#   'friends': 0.0,
#   'beer': 0.0,
#   'back': 0.0,
#   'talking': 0.0,
#   'shes': 0.0,
#   'starts': 0.0,
#   'should': 0.0,
#   'cowboys': 0.0,
#   'head': 0.0,
#   'soon': 0.0,
#   'wait': 0.0,
#   'work': 0.0,
#   'again': 1.6094379124341003,
#   'cause': 0.0,
#   'begins': 4.605170185988092,
#   'jack': 0.0,
#   'ends': 0.0,
#   'leave': 0.0,
#   'going': 0.0,
#   'home': 0.0,
#   'were': 1.3862943611198906,
#   'fun': 0.0,
#   'threatening': 0.0,
#   'late': 0.0,
#   'wearing': 0.0,
#   'have': 1.5970153924355432,
#   'busting': 0.0,
#   'sleep': 0.0,
#   'morning': 0.0,
#   'party': 0.0,
#   'with': 1.3862943611198906,
#   'theyre': 3.2188758248682006,
#   'who': 0.7985076962177716,
#   'just': 0.0,
#   'yeah': 0.0,
#   'shirt': 0.0,
#   'goes': 0.0,
#   'nightstand': 0.0,
#   'its': 0.43078291609245434,
#   'yes': 0.0,
#   'road': 0.0,
#   'ive': 0.0,
#   'this': 0.0,
#   'breakfast': 0.0,
#   'kitchen': 0.0,
#   'keep': 0.0,
#   'say': 0.0,
#   'is': 0.44628710262841953,
#   'been': 0.0,
#   'thats': 0.0,
#   'im': 0.0,
#   'foreman': 0.0,
#   'two': 2.772588722239781,
#   'way': 0.0,
#   'buddies': 0.0,
#   'crime': 2.995732273553991,
#   'open': 1.3862943611198906,
#   'last': 2.302585092994046,
#   'feeling': 1.6094379124341003,
#   'swing': 2.995732273553991,
#   'right': 1.2039728043259361,
#   'knocks': 5.991464547107982,
#   'get': 1.3862943611198906,
#   'need': 0.9162907318741551,
#   'four': 3.2188758248682006,
#   'car': 1.6094379124341003,
#   'worked': 2.995732273553991,
#   'down': 1.0216512475319814,
#   'turns': 5.991464547107982,
#   'something': 1.0498221244986776,
#   'sees': 2.302585092994046,
#   'says': 2.302585092994046,
#   'would': 1.8971199848858813,
#   'face': 3.2188758248682006,
#   'beach': 2.995732273553991,
#   'em': 3.2188758248682006,
#   'gets': 2.302585092994046,
#   'problem': 2.302585092994046,
#   'thieving': 2.995732273553991,
#   'dessert': 2.995732273553991,
#   'monday': 2.995732273553991,
#   'ill': 1.6094379124341003,
#   'knows': 1.8971199848858813,
#   'dinner': 2.995732273553991,
#   'gone': 2.995732273553991,
#   'heading': 2.995732273553991,
#   'pickup': 5.991464547107982,
#   'perfect': 2.995732273553991,
#   'plan': 2.302585092994046,
#   'complete': 2.995732273553991,
#   'somethings': 1.8971199848858813,
#   'gifted': 2.995732273553991,
#   'amen': 1.8971199848858813,
#   'switch': 2.302585092994046,
#   'score': 2.302585092994046,
#   'youre': 0.9162907318741551,
#   'lets': 2.772588722239781,
#   'evening': 2.995732273553991,
#   'set': 1.6094379124341003,
#   'flash': 2.995732273553991,
#   'must': 2.995732273553991,
#   'light': 1.8971199848858813,
#   'afternoon': 2.995732273553991,
#   'like': 0.43078291609245434,
#   'happened': 2.995732273553991,
#   'clydes': 2.995732273553991,
#   'seen': 2.302585092994046,
#   'him': 9.210340371976184,
#   'once': 2.995732273553991,
#   'petty': 2.995732273553991,
#   'thousand': 2.302585092994046,
#   'clyde': 5.991464547107982,
#   'standing': 2.302585092994046,
#   'times': 1.6094379124341003,
#   'swaps': 2.995732273553991,
#   'hit': 3.2188758248682006,
#   'more': 1.6094379124341003,
#   'let': 1.3862943611198906,
#   'floor': 4.605170185988092,
#   'sleight': 2.995732273553991,
#   'grabs': 2.995732273553991,
#   'end': 1.6094379124341003,
#   'seems': 2.995732273553991,
#   'bout': 2.302585092994046,
#   'not': 0.7985076962177716,
#   'if': 0.9162907318741551,
#   'sands': 2.995732273553991,
#   'run': 1.8971199848858813,
#   'find': 1.6094379124341003,
#   'hand': 2.302585092994046,
#   'but': 1.0700248318161971,
#   'jump': 2.302585092994046,
#   'armored': 2.995732273553991,
#   'before': 2.302585092994046,
#   'stopping': 2.995732273553991,
#   'dealer': 2.995732273553991,
#   'away': 1.2039728043259361,
#   'joann': 5.991464547107982,
#   'guards': 2.995732273553991,
#   'window': 2.995732273553991,
#   'na': 0.9162907318741551,
#   'happy': 2.995732273553991,
#   'west': 2.995732273553991,
#   'conniving': 2.995732273553991,
#   'hes': 3.7942399697717626,
#   'at': 2.0996442489973552,
#   'hustle': 2.995732273553991,
#   'asks': 2.995732273553991,
#   'man': 1.6094379124341003,
#   'bang': 117.43183974269634,
#   'someday': 2.995732273553991,
#   'hiding': 2.995732273553991,
#   'see': 0.6931471805599453,
#   'good': 1.3862943611198906,
#   'door': 8.987196820661973,
#   'guard': 14.978661367769954,
#   'shows': 2.995732273553991,
#   'money': 1.8971199848858813,
#   'cash': 8.987196820661973,
#   'desert': 2.995732273553991,
#   'master': 2.995732273553991,
#   'house': 2.995732273553991,
#   'meet': 1.6094379124341003,
#   'friday': 2.302585092994046,
#   'bags': 5.991464547107982,
#   'bangs': 2.995732273553991,
#   'play': 1.8971199848858813,
#   'doors': 2.302585092994046,
#   'both': 2.995732273553991,
#   'ways': 1.6094379124341003,
#   'gon': 0.7985076962177716,
#   'fire': 0.0,
#   'rest': 0.0,
#   'what': 0.0,
#   'after': 0.0,
#   'driving': 0.0,
#   'talk': 0.0,
#   'hell': 0.0,
#   'fought': 0.0,
#   'lady': 0.0,
#   'high': 0.0,
#   'better': 0.0,
#   'crazy': 0.0,
#   'hope': 0.0,
#   'burning': 0.0,
#   'whiskey': 0.0,
#   'wine': 0.0,
#   'rejoin': 0.0,
#   'polite': 0.0,
#   'probably': 0.0,
#   'damn': 0.0,
#   'desire': 0.0,
#   'walking': 0.0,
#   'handsome': 0.0,
#   'no': 0.0,
#   'try': 0.0,
#   'always': 0.0,
#   'mans': 0.0,
#   'nice': 0.0,
#   'hoping': 0.0,
#   'show': 0.0,
#   'listens': 0.0,
#   'best': 0.0,
#   'dont': 0.0,
#   'refined': 0.0,
#   'pretty': 0.0,
#   'sure': 0.0,
#   'than': 0.0,
#   'miss': 0.0,
#   'loved': 0.0,
#   'knowing': 0.0,
#   'missing': 0.0,
#   'patient': 0.0,
#   'romantic': 0.0,
#   'same': 0.0,
#   'i': 0.0,
#   'showing': 0.0,
#   'move': 0.0,
#   'pass': 0.0,
#   'one': 0.0,
#   'ones': 0.0,
#   'nowhere': 0.0,
#   'hide': 0.0,
#   'unleash': 0.0,
#   'chosen': 0.0,
#   'storm': 0.0,
#   'drumming': 0.0,
#   'life': 0.0,
#   'pissed': 0.0,
#   'give': 0.0,
#   'waited': 0.0,
#   'young': 0.0,
#   'makin': 0.0,
#   'prove': 0.0,
#   'different': 0.0,
#   'them': 0.0,
#   'running': 0.0,
#   'some': 0.0,
#   'coming': 0.0,
#   'pure': 0.0,
#   'hear': 0.0,
#   'ever': 0.0,
#   'adrenaline': 0.0,
#   'ready': 0.0,
#   'chance': 0.0,
#   'multitudes': 0.0,
#   'whole': 0.0,
#   'kill': 0.0,
#   'dance': 0.0,
#   'dial': 0.0,
#   'want': 0.0,
#   'fates': 0.0,
#   'god': 0.0,
#   'long': 0.0,
#   'kickin': 0.0,
#   'forgotten': 0.0,
#   'got': 0.0,
#   'youve': 0.0,
#   'your': 0.0,
#   'inside': 0.0,
#   'drummer': 0.0,
#   'world': 0.0,
#   'byway': 0.0,
#   'off': 0.0,
#   'has': 0.0,
#   'beast': 0.0,
#   'stretch': 0.0,
#   'standin': 0.0,
#   'done': 0.0,
#   'lift': 0.0,
#   'knees': 0.0,
#   'second': 0.0,
#   'come': 0.0,
#   'desperate': 0.0,
#   'really': 0.0,
#   'true': 0.0,
#   'loves': 0.0,
#   'color': 0.0,
#   'changed': 0.0,
#   'isnt': 0.0,
#   'hed': 0.0,
#   'truly': 0.0,
#   'whoever': 0.0,
#   'prayer': 0.0,
#   'take': 0.0,
#   'shoulder': 0.0,
#   'lanes': 0.0,
#   'sitting': 0.0,
#   'us': 0.0,
#   'guys': 0.0,
#   'hers': 0.0,
#   'realize': 0.0,
#   'knew': 0.0,
#   'alright': 0.0,
#   'today': 0.0,
#   'fast': 0.0,
#   'can': 0.0,
#   'hard': 0.0,
#   'oclock': 0.0,
#   'nothings': 0.0,
#   'worse': 0.0,
#   'everything': 0.0,
#   'simply': 0.0,
#   'youd': 0.0,
#   'looks': 0.0,
#   'tonight': 0.0,
#   'crawl': 0.0,
#   'traffic': 0.0,
#   'finally': 0.0,
#   'five': 0.0,
#   'then': 0.0,
#   'falls': 0.0,
#   'wreck': 0.0,
#   'close': 0.0,
#   'much': 0.0,
#   'do': 0.0,
#   'tell': 0.0,
#   'crash': 0.0,
#   'changes': 0.0,
#   'model': 0.0,
#   'dying': 0.0,
#   'whoa': 0.0,
#   'lay': 0.0,
#   'save': 0.0,
#   'name': 0.0,
#   'explain': 0.0,
#   'heart': 0.0,
#   'love': 0.0,
#   'counting': 0.0,
#   'quite': 0.0,
#   'smile': 0.0,
#   'circumstance': 0.0,
#   'baby': 0.0,
#   'kind': 0.0,
#   'may': 0.0,
#   'hazy': 0.0,
#   'thinking': 0.0,
#   'known': 0.0,
#   'style': 0.0,
#   'pray': 0.0,
#   'cant': 0.0,
#   'black': 0.0,
#   'drive': 0.0,
#   'moving': 0.0,
#   'blind': 0.0,
#   'blue': 0.0,
#   'romance': 0.0,
#   'swore': 0.0,
#   'go': 0.0,
#   'victim': 0.0,
#   'brand': 0.0,
#   'comes': 0.0,
#   'trance': 0.0,
#   'felt': 0.0,
#   'shake': 0.0,
#   'youll': 0.0,
#   'fool': 0.0,
#   'things': 0.0,
#   'stubborn': 0.0,
#   'rules': 0.0,
#   'make': 0.0,
#   'pride': 0.0,
#   'anything': 0.0,
#   'trying': 0.0,
#   'settle': 0.0,
#   'ask': 0.0,
#   'push': 0.0,
#   'walls': 0.0,
#   'wont': 0.0,
#   'fall': 0.0,
#   'wrong': 0.0,
#   'freedom': 0.0,
#   'beg': 0.0,
#   'am': 0.0,
#   'figure': 0.0,
#   'maybe': 0.0,
#   'stick': 0.0,
#   'repeat': 0.0,
#   'shell': 0.0,
#   'around': 0.0,
#   'building': 0.0,
#   'space': 0.0,
#   'id': 0.0,
#   'start': 0.0,
#   'spending': 0.0,
#   'put': 0.0,
#   'another': 0.0,
#   'onto': 0.0,
#   'ta': 0.0,
#   'siena': 0.0,
#   'wherever': 0.0,
#   'cabanas': 0.0,
#   'means': 0.0,
#   'vienna': 0.0,
#   'south': 0.0,
#   'well': 0.0,
#   'sundown': 0.0,
#   'needs': 0.0,
#   'bet': 0.0,
#   'champaignurbana': 0.0,
#   'sweet': 0.0,
#   'even': 0.0,
#   'atlanta': 0.0,
#   'indiana': 0.0,
#   'wake': 0.0,
#   'still': 0.0,
#   'loving': 0.0,
#   'swear': 0.0,
#   'western': 0.0,
#   'havana': 0.0,
#   'track': 0.0,
#   'lord': 0.0,
#   'unwind': 0.0,
#   'montana': 0.0,
#   'chantin': 0.0,
#   'alabama': 0.0,
#   'laughing': 0.0,
#   'singing': 0.0,
#   'enough': 0.0,
#   'somewhere': 0.0,
#   'savannah': 0.0,
#   'rocking': 0.0,
#   'guyana': 0.0,
#   'our': 0.0,
#   'here': 0.0,
#   'louisiana': 0.0,
#   'rockin': 0.0,
#   'pajamas': 0.0,
#   'wan': 0.0,
#   'rollin': 0.0,
#   'muncie': 0.0,
#   'snakin': 0.0,
#   'dancing': 0.0,
#   'sun': 0.0,
#   'weekend': 0.0,
#   'operater': 0.0,
#   '911': 0.0,
#   'workin': 0.0,
#   'emergency': 0.0,
#   'land': 0.0,
#   'redhead': 0.0,
#   'mercy': 0.0,
#   'swingin': 0.0,
#   'sign': 0.0,
#   'neon': 0.0,
#   'country': 0.0,
# ...
#   'he': 0.0,
#   'gates': 0.0,
#   'jc': 0.0,
#   'there': 1.2039728043259361,
#   'adds': 0.0,
#   'water': 0.0,
#   'all': 1.1157177565710488,
#   'kept': 0.0,
#   'borderline': 0.0,
#   'jesus': 0.0,
#   'free': 0.0,
#   'big': 0.0,
#   'red': 0.0,
#   'her': 0.0,
#   'state': 0.0,
#   'as': 0.0,
#   'gift': 0.0,
#   'japan': 0.0,
#   'uncle': 0.0,
#   'pearly': 0.0,
#   'nimbus': 0.0,
#   'heard': 0.0,
#   'time': 0.0,
#   'trinity': 0.0,
#   'letters': 0.0,
#   'for': 8.615658321849086,
#   'underlined': 0.0,
#   'frozen': 0.0,
#   'about': 0.0,
#   'highway': 0.0,
#   'in': 0.4214420626313054,
#   'bullet': 0.0,
#   'oh': 0.0,
#   'call': 0.0,
#   'leaf': 0.0,
#   'up': 0.0,
#   'hummed': 0.0,
#   'of': 0.8630462173553426,
#   'forever': 0.0,
#   'miracle': 0.0,
#   'vincent': 0.0,
#   'sunshine': 0.0,
#   'spent': 0.0,
#   'ear': 0.0,
#   'it': 0.22314355131420976,
#   'six': 0.0,
#   'runneth': 0.0,
#   'team': 0.0,
#   'never': 0.0,
#   'each': 0.0,
#   'though': 0.0,
#   'working': 0.0,
#   'aching': 0.0,
#   'are': 0.0,
#   'doesnt': 0.0,
#   'over': 0.0,
#   'lane': 0.0,
#   'wanting': 0.0,
#   'guess': 0.0,
#   'friends': 0.0,
#   'beer': 0.0,
#   'back': 1.2039728043259361,
#   'talking': 0.0,
#   'shes': 0.0,
#   'starts': 0.0,
#   'should': 0.0,
#   'cowboys': 0.0,
#   'head': 0.0,
#   'soon': 0.0,
#   'wait': 0.0,
#   'work': 0.0,
#   'again': 8.047189562170502,
#   'cause': 2.0794415416798357,
#   'begins': 0.0,
#   'jack': 0.0,
#   'ends': 0.0,
#   'leave': 0.0,
#   'going': 0.0,
#   'home': 0.0,
#   'were': 0.0,
#   'fun': 0.0,
#   'threatening': 0.0,
#   'late': 0.0,
#   'wearing': 0.0,
#   'have': 0.0,
#   'busting': 0.0,
#   'sleep': 0.0,
#   'morning': 0.0,
#   'party': 0.0,
#   'with': 0.6931471805599453,
#   'theyre': 0.0,
#   'who': 3.9925384810888582,
#   'just': 1.292348748277363,
#   'yeah': 0.0,
#   'shirt': 0.0,
#   'goes': 0.0,
#   'nightstand': 0.0,
#   'its': 1.292348748277363,
#   'yes': 0.0,
#   'road': 1.8971199848858813,
#   'ive': 0.0,
#   'this': 2.1539145804622715,
#   'breakfast': 0.0,
#   'kitchen': 0.0,
#   'keep': 0.0,
#   'say': 0.0,
#   'is': 0.44628710262841953,
#   'been': 0.0,
#   'thats': 0.6931471805599453,
#   'im': 5.600177909201906,
#   'foreman': 0.0,
#   'two': 0.0,
#   'way': 0.0,
#   'buddies': 0.0,
#   'crime': 0.0,
#   'open': 0.0,
#   'last': 0.0,
#   'feeling': 0.0,
#   'swing': 0.0,
#   'right': 0.0,
#   'knocks': 0.0,
#   'get': 0.0,
#   'need': 1.8325814637483102,
#   'four': 0.0,
#   'car': 0.0,
#   'worked': 0.0,
#   'down': 0.5108256237659907,
#   'turns': 0.0,
#   'something': 0.0,
#   'sees': 0.0,
#   'says': 0.0,
#   'would': 0.0,
#   'face': 0.0,
#   'beach': 0.0,
#   'em': 0.0,
#   'gets': 0.0,
#   'problem': 0.0,
#   'thieving': 0.0,
#   'dessert': 0.0,
#   'monday': 0.0,
#   'ill': 11.266065387038703,
#   'knows': 0.0,
#   'dinner': 0.0,
#   'gone': 0.0,
#   'heading': 0.0,
#   'pickup': 0.0,
#   'perfect': 0.0,
#   'plan': 0.0,
#   'complete': 0.0,
#   'somethings': 0.0,
#   'gifted': 0.0,
#   'amen': 0.0,
#   'switch': 0.0,
#   'score': 0.0,
#   'youre': 0.0,
#   'lets': 0.0,
#   'evening': 0.0,
#   'set': 0.0,
#   'flash': 0.0,
#   'must': 0.0,
#   'light': 0.0,
#   'afternoon': 0.0,
#   'like': 0.0,
#   'happened': 0.0,
#   'clydes': 0.0,
#   'seen': 0.0,
#   'him': 0.0,
#   'once': 0.0,
#   'petty': 0.0,
#   'thousand': 0.0,
#   'clyde': 0.0,
#   'standing': 0.0,
#   'times': 1.6094379124341003,
#   'swaps': 0.0,
#   'hit': 0.0,
#   'more': 0.0,
#   'let': 0.0,
#   'floor': 0.0,
#   'sleight': 0.0,
#   'grabs': 0.0,
#   'end': 0.0,
#   'seems': 0.0,
#   'bout': 0.0,
#   'not': 0.0,
#   'if': 6.414035123119086,
#   'sands': 0.0,
#   'run': 1.8971199848858813,
#   'find': 0.0,
#   'hand': 0.0,
#   'but': 0.0,
#   'jump': 0.0,
#   'armored': 0.0,
#   'before': 0.0,
#   'stopping': 0.0,
#   'dealer': 0.0,
#   'away': 0.0,
#   'joann': 0.0,
#   'guards': 0.0,
#   'window': 0.0,
#   'na': 0.0,
#   'happy': 0.0,
#   'west': 0.0,
#   'conniving': 0.0,
#   'hes': 0.0,
#   'at': 1.0498221244986776,
#   'hustle': 0.0,
#   'asks': 0.0,
#   'man': 0.0,
#   'bang': 0.0,
#   'someday': 0.0,
#   'hiding': 0.0,
#   'see': 2.0794415416798357,
#   'good': 1.3862943611198906,
#   'door': 0.0,
#   'guard': 0.0,
#   'shows': 0.0,
#   'money': 0.0,
#   'cash': 0.0,
#   'desert': 0.0,
#   'master': 0.0,
#   'house': 0.0,
#   'meet': 0.0,
#   'friday': 0.0,
#   'bags': 0.0,
#   'bangs': 0.0,
#   'play': 0.0,
#   'doors': 0.0,
#   'both': 0.0,
#   'ways': 0.0,
#   'gon': 8.783584658395489,
#   'fire': 0.0,
#   'rest': 0.0,
#   'what': 0.5978370007556204,
#   'after': 0.0,
#   'driving': 0.0,
#   'talk': 0.0,
#   'hell': 4.605170185988092,
#   'fought': 0.0,
#   'lady': 0.0,
#   'high': 0.0,
#   'better': 0.0,
#   'crazy': 0.0,
#   'hope': 0.0,
#   'burning': 0.0,
#   'whiskey': 0.0,
#   'wine': 0.0,
#   'rejoin': 0.0,
#   'polite': 0.0,
#   'probably': 0.0,
#   'damn': 0.0,
#   'desire': 0.0,
#   'walking': 0.0,
#   'handsome': 0.0,
#   'no': 0.0,
#   'try': 0.0,
#   'always': 2.772588722239781,
#   'mans': 0.0,
#   'nice': 0.0,
#   'hoping': 0.0,
#   'show': 0.0,
#   'listens': 0.0,
#   'best': 0.0,
#   'dont': 0.3566749439387324,
#   'refined': 0.0,
#   'pretty': 0.0,
#   'sure': 0.0,
#   'than': 0.0,
#   'miss': 0.0,
#   'loved': 0.0,
#   'knowing': 0.0,
#   'missing': 0.0,
#   'patient': 0.0,
#   'romantic': 0.0,
#   'same': 3.7942399697717626,
#   'i': 2.4545790644563072,
#   'showing': 0.0,
#   'move': 0.0,
#   'pass': 0.0,
#   'one': 0.0,
#   'ones': 0.0,
#   'nowhere': 0.0,
#   'hide': 0.0,
#   'unleash': 0.0,
#   'chosen': 0.0,
#   'storm': 0.0,
#   'drumming': 0.0,
#   'life': 3.6119184129778086,
#   'pissed': 0.0,
#   'give': 0.0,
#   'waited': 0.0,
#   'young': 0.0,
#   'makin': 0.0,
#   'prove': 0.0,
#   'different': 0.0,
#   'them': 0.0,
#   'running': 0.0,
#   'some': 0.0,
#   'coming': 0.0,
#   'pure': 0.0,
#   'hear': 0.0,
#   'ever': 0.0,
#   'adrenaline': 0.0,
#   'ready': 3.2188758248682006,
#   'chance': 0.0,
#   'multitudes': 0.0,
#   'whole': 0.0,
#   'kill': 6.907755278982138,
#   'dance': 0.0,
#   'dial': 0.0,
#   'want': 0.0,
#   'fates': 0.0,
#   'god': 1.2039728043259361,
#   'long': 0.0,
#   'kickin': 0.0,
#   'forgotten': 0.0,
#   'got': 1.1956740015112408,
#   'youve': 0.0,
#   'your': 0.5108256237659907,
#   'inside': 0.0,
#   'drummer': 0.0,
#   'world': 1.3862943611198906,
#   'byway': 0.0,
#   'off': 0.0,
#   'has': 0.0,
#   'beast': 0.0,
#   'stretch': 0.0,
#   'standin': 0.0,
#   'done': 0.0,
#   'lift': 0.0,
#   'knees': 0.0,
#   'second': 0.0,
#   'come': 0.0,
#   'desperate': 0.0,
#   'really': 0.0,
#   'true': 0.0,
#   'loves': 0.0,
#   'color': 0.0,
#   'changed': 0.0,
#   'isnt': 0.0,
#   'hed': 0.0,
#   'truly': 0.0,
#   'whoever': 0.0,
#   'prayer': 0.0,
#   'take': 4.1992884979947105,
#   'shoulder': 0.0,
#   'lanes': 0.0,
#   'sitting': 0.0,
#   'us': 0.0,
#   'guys': 0.0,
#   'hers': 0.0,
#   'realize': 0.0,
#   'knew': 0.0,
#   'alright': 0.0,
#   'today': 2.302585092994046,
#   'fast': 0.0,
#   'can': 0.0,
#   'hard': 1.8971199848858813,
#   'oclock': 0.0,
#   'nothings': 0.0,
#   'worse': 0.0,
#   'everything': 0.0,
#   'simply': 0.0,
#   'youd': 0.0,
#   'looks': 0.0,
#   'tonight': 0.0,
#   'crawl': 0.0,
#   'traffic': 0.0,
#   'finally': 0.0,
#   'five': 0.0,
#   'then': 6.437751649736401,
#   'falls': 0.0,
#   'wreck': 0.0,
#   'close': 0.0,
#   'much': 0.0,
#   'do': 0.0,
#   'tell': 3.6119184129778086,
#   'crash': 0.0,
#   'changes': 0.0,
#   'model': 0.0,
#   'dying': 0.0,
#   'whoa': 0.0,
#   'lay': 0.0,
#   'save': 11.51292546497023,
#   'name': 0.0,
#   'explain': 0.0,
#   'heart': 1.6094379124341003,
#   'love': 0.0,
#   'counting': 0.0,
#   'quite': 0.0,
#   'smile': 0.0,
#   'circumstance': 0.0,
#   'baby': 0.0,
#   'kind': 0.0,
#   'may': 0.0,
#   'hazy': 0.0,
#   'thinking': 0.0,
#   'known': 0.0,
#   'style': 0.0,
#   'pray': 6.907755278982138,
#   'cant': 0.0,
#   'black': 0.0,
#   'drive': 0.0,
#   'moving': 0.0,
#   'blind': 0.0,
#   'blue': 0.0,
#   'romance': 0.0,
#   'swore': 0.0,
#   'go': 3.6651629274966204,
#   'victim': 0.0,
#   'brand': 0.0,
#   'comes': 0.0,
#   'trance': 0.0,
#   'felt': 0.0,
#   'shake': 0.0,
#   'youll': 0.0,
#   'fool': 0.0,
#   'things': 0.0,
#   'stubborn': 0.0,
#   'rules': 0.0,
#   'make': 0.0,
#   'pride': 0.0,
#   'anything': 0.0,
#   'trying': 0.0,
#   'settle': 0.0,
#   'ask': 0.0,
#   'push': 0.0,
#   'walls': 0.0,
#   'wont': 0.0,
#   'fall': 0.0,
#   'wrong': 0.0,
#   'freedom': 0.0,
#   'beg': 0.0,
#   'am': 0.0,
#   'figure': 0.0,
#   'maybe': 0.0,
#   'stick': 0.0,
#   'repeat': 0.0,
#   'shell': 0.0,
#   'around': 0.0,
#   'building': 2.302585092994046,
#   'space': 0.0,
#   'id': 0.0,
#   'start': 0.0,
#   'spending': 0.0,
#   'put': 0.0,
#   'another': 0.0,
#   'onto': 0.0,
#   'ta': 2.772588722239781,
#   'siena': 0.0,
#   'wherever': 0.0,
#   'cabanas': 0.0,
#   'means': 0.0,
#   'vienna': 0.0,
#   'south': 0.0,
#   'well': 0.0,
#   'sundown': 0.0,
#   'needs': 0.0,
#   'bet': 0.0,
#   'champaignurbana': 0.0,
#   'sweet': 0.0,
#   'even': 1.8971199848858813,
#   'atlanta': 0.0,
#   'indiana': 0.0,
#   'wake': 0.0,
#   'still': 0.0,
#   'loving': 0.0,
#   'swear': 0.0,
#   'western': 0.0,
#   'havana': 0.0,
#   'track': 0.0,
#   'lord': 0.0,
#   'unwind': 0.0,
#   'montana': 0.0,
#   'chantin': 0.0,
#   'alabama': 0.0,
#   'laughing': 0.0,
#   'singing': 0.0,
#   'enough': 0.0,
#   'somewhere': 0.0,
#   'savannah': 0.0,
#   'rocking': 0.0,
#   'guyana': 0.0,
#   'our': 0.0,
#   'here': 0.0,
#   'louisiana': 0.0,
#   'rockin': 0.0,
#   'pajamas': 0.0,
#   'wan': 0.0,
#   'rollin': 0.0,
#   'muncie': 0.0,
#   'snakin': 0.0,
#   'dancing': 0.0,
#   'sun': 0.0,
#   'weekend': 0.0,
#   'operater': 0.0,
#   '911': 0.0,
#   'workin': 0.0,
#   'emergency': 0.0,
#   'land': 0.0,
#   'redhead': 0.0,
#   'mercy': 0.0,
#   'swingin': 0.0,
#   'sign': 0.0,
#   'neon': 0.0,
#   'country': 0.0,
#   'thirstin': 0.0,
#   'intensive': 0.0,
#   'dirt': 0.0,
#   'afraid': 0.0,
#   'honkytonk': 0.0,
#   'piece': 0.0,
#   'thinkin': 0.0,
#   'brunette': 0.0,
#   'hurtin': 0.0,
#   'anywhere': 0.0,
#   'mapped': 0.0,
#   'nursin': 0.0,
#   'tried': 0.0,
#   'thumpin': 0.0,
#   'jumpin': 0.0,
#   'hopin': 0.0,
#   'broken': 0.0,
#   'little': 0.0,
#   'promised': 0.0,
#   'band': 0.0,
#   'sound': 0.0,
#   'karaoke': 0.0,
#   'blonde': 0.0,
#   'wheres': 0.0,
#   'angel': 0.0,
#   'care': 0.0,
#   'operator': 0.0,
#   'n': 0.0,
#   'later': 0.0,
#   'week': 0.0,
#   'aint': 0.9162907318741551,
#   'help': 0.0,
#   'remedy': 0.0,
#   'phone': 0.0,
#   'siri': 0.0,
#   'hang': 0.0,
#   'glowin': 0.0,
#   'answer': 0.0,
#   'jukejoint': 0.0,
#   'people': 0.0,
#   'moral': 0.0,
#   'live': 11.382719909315288,
#   'calculated': 0.0,
#   'endorsin': 0.0,
#   'skin': 0.0,
#   'small': 0.0,
#   'recognize': 0.0,
#   'covered': 0.0,
#   'entitled': 0.0,
#   'dealin': 0.0,
#   'stay': 0.0,
#   'nobody': 0.0,
#   'winnin': 0.0,
#   'shit': 0.0,
#   'ya': 0.0,
#   'bad': 0.0,
#   'ego': 0.0,
#   'promises': 0.0,
#   'fuck': 0.0,
#   'kinda': 0.0,
#   'buildin': 0.0,
#   'feel': 0.0,
#   'motherfucker': 0.0,
#   'tryna': 1.8971199848858813,
#   'realest': 0.0,
#   'did': 0.0,
#   'days': 0.0,
#   'breathin': 0.0,
#   'bring': 0.0,
#   'closer': 0.0,
#   'nothin': 0.0,
#   'prayin': 0.0,
#   'false': 0.0,
#   'talkin': 0.0,
#   'involved': 0.0,
#   'stars': 0.0,
#   'expectations': 0.0,
#   'credit': 0.0,
#   'lamar': 1.5970153924355432,
#   'sza': 0.0,
#   'confidence': 0.0,
#   'percentage': 0.0,
#   'approach': 0.0,
#   'conversation': 0.0,
#   'reason': 0.0,
#   'truth': 0.0,
#   'confrontation': 0.0,
#   'hate': 0.0,
#   'important': 0.0,
#   'thanks': 0.0,
#   'hoped': 0.0,
#   'game': 0.0,
#   'kendrick': 1.5970153924355432,
#   'wouldnt': 0.0,
#   'rebound': 0.0,
#   'congratulations': 0.0,
#   'might': 0.0,
#   'story': 0.0,
#   'losin': 0.0,
#   'invite': 0.0,
#   'momma': 0.0,
#   'morgue': 0.0,
#   'look': 1.3862943611198906,
#   'hours': 0.0,
#   'haunt': 0.0,
#   'corrupt': 0.0,
#   'sword': 0.0,
#   'cryin': 0.0,
#   'making': 0.0,
#   'lee': 0.0,
#   'contribution': 0.0,
#   'alone': 7.588479939543525,
#   'power': 0.0,
#   'had': 0.0,
#   'nigga': 0.0,
#   'why': 0.0,
#   'castin': 0.0,
#   'carryin': 0.0,
#   'uh': 0.0,
#   'fucked': 0.0,
#   'turned': 0.0,
#   'easy': 0.0,
#   'knowow': 0.0,
#   'views': 0.0,
#   'city': 0.0,
#   'fly': 0.0,
#   'body': 1.8971199848858813,
#   'travel': 0.0,
#   'doin': 0.0,
#   'beams': 0.0,
#   'ayy': 0.0,
#   'dust': 0.0,
#   'khalid': 0.0,
#   'brother': 0.0,
#   'swae': 0.0,
#   'niggas': 0.0,
#   'most': 0.0,
#   'knowowow': 0.0,
#   'lose': 0.0,
#   'goin': 0.0,
#   'safe': 0.0,
#   'radion': 0.0,
#   'everywhere': 0.0,
#   'somethin': 0.0,
#   'section': 0.0,
#   'vibrant': 0.0,
#   'movin': 0.0,
#   'many': 2.302585092994046,
#   'pick': 0.0,
#   'only': 0.0,
#   'roll': 0.0,
#   'finesse': 0.0,
#   'until': 0.0,
#   'ward': 0.0,
#   'rims': 0.0,
#   'tangle': 0.0,
#   'genocide': 0.0,
#   'girls': 0.0,
#   'church': 0.0,
#   'figurines': 0.0,
#   'scarface': 2.302585092994046,
#   'other': 0.0,
#   'blakrok': 0.0,
#   'coons': 0.0,
#   'signatures': 0.0,
#   'nothing': 0.0,
#   'friend': 0.0,
#   'drown': 0.0,
#   'antidote': 0.0,
#   'cleaver': 0.0,
#   'rover': 0.0,
#   'roar': 0.0,
#   'bars': 0.0,
#   'blues': 0.0,
#   'size': 0.0,
#   'drawn': 0.0,
#   'dog': 0.0,
#   'crushing': 0.0,
#   'toâ€': 0.0,
#   'half': 0.0,
#   'stack': 0.0,
#   'cyborg': 0.0,
#   'aura': 0.0,
#   'surface': 0.0,
#   'freeze': 0.0,
#   'poison': 0.0,
#   'bend': 0.0,
#   'mouth': 0.0,
#   'jackson': 0.0,
#   'chase': 0.0,
#   'coupe': 0.0,
#   'wide': 0.0,
#   'obscene': 0.0,
#   'flex': 0.0,
#   'spit': 0.0,
#   'slick': 0.0,
#   'die': 6.907755278982138,
#   'break': 0.0,
#   'yugen': 0.0,
#   'crimes': 0.0,
#   'sittin': 0.0,
#   'cover': 0.0,
#   'millipede': 0.0,
#   'tend': 0.0,
#   'chords': 0.0,
#   'trapped': 0.0,
#   'butterflies': 0.0,
#   'spitting': 0.0,
#   'trees': 0.0,
#   'shoot': 0.0,
#   'lasers': 0.0,
#   'takes': 0.0,
#   'spinning': 0.0,
#   'benz': 0.0,
#   'submarine': 0.0,
#   'flowers': 0.0,
#   'hirez': 0.0,
#   'mines': 0.0,
#   'staples': 0.0,
#   'own': 11.382719909315288,
#   'hurts': 0.0,
#   'ground': 4.605170185988092,
#   'seasoned': 0.0,
#   'pity': 0.0,
#   'vince': 0.0,
#   'swimming': 0.0,
#   'gotham': 0.0,
#   'livin': 2.302585092994046,
#   'defeat': 0.0,
#   'rhymes': 0.0,
#   'eyes': 0.0,
#   'attack': 0.0,
#   'brain': 0.0,
#   'kathleen': 0.0,
#   'lemons': 0.0,
#   'ball': 0.0,
#   'cab': 0.0,
#   'bleeding': 0.0,
#   'strength': 0.0,
#   'opps': 0.0,
#   'blades': 0.0,
#   'armory': 0.0,
#   'sinister': 0.0,
#   'machine': 0.0,
#   'rubber': 0.0,
#   'streets': 2.302585092994046,
#   'behind': 0.0,
#   'getting': 0.0,
#   'belittles': 0.0,
#   'beam': 0.0,
#   '20': 0.0,
#   'side': 0.0,
#   'blame': 0.0,
#   'sin': 0.0,
#   'speed': 0.0,
#   'zone': 0.0,
#   'raw': 0.0,
#   'taxi': 0.0,
#   'committing': 0.0,
#   'clean': 0.0,
#   'millie': 0.0,
#   'alive': 0.0,
#   'turn': 0.0,
#   'colours': 0.0,
#   'keys': 0.0,
#   'worth': 0.0,
#   'bodies': 0.0,
#   'lime': 0.0,
#   'psych': 0.0,
#   'yall': 0.0,
#   'lioness': 0.0,
#   'tendons': 0.0,
#   'subliminal': 0.0,
#   'zoom': 0.0,
#   'weaver': 0.0,
#   'criminal': 0.0,
#   'brothers': 0.0,
#   'thing': 0.0,
#   'bought': 0.0,
#   'thought': 0.0,
#   'verbal': 0.0,
#   'system': 0.0,
#   '”': 0.0,
#   'radar': 0.0,
#   'debt': 0.0,
#   'thatll': 0.0,
#   'judge': 0.0,
#   'check': 0.0,
#   'hey': 25.328436022934504,
#   'brown': 0.0,
#   'punch': 0.0,
#   'administer': 0.0,
#   'top': 1.6094379124341003,
#   'gave': 0.0,
#   'watch': 0.0,
#   'stand': 0.0,
#   'gettin': 0.0,
#   'any': 0.0,
#   'dead': 0.0,
#   'rhyme': 0.0,
#   'censored': 0.0,
#   'perimeter': 0.0,
#   'stop': 0.0,
#   'sometimes': 0.0,
#   'offends': 0.0,
#   'sacrifice': 0.0,
#   'margin': 0.0,
#   'satisfied': 0.0,
#   'smith': 0.0,
#   'triggering': 0.0,
#   'opinion': 0.0,
#   'shame': 0.0,
#   'part': 0.0,
#   'fears': 0.0,
#   'feels': 0.0,
#   'ohh': 0.0,
#   'voicing': 0.0,
#   'sorry': 0.0,
#   'scared': 0.0,
#   'change': 0.0,
#   'subject': 0.0,
#   'wins': 0.0,
#   'depending': 0.0,
#   'tryin': 0.0,
#   'real': 0.0,
#   'course': 0.0,
#   'letter': 0.0,
#   'loss': 0.0,
#   'anymore': 0.0,
#   'indifferent': 0.0,
#   'yah': 0.0,
#   'homecoming': 0.0,
#   'too': 0.0,
#   'jorja': 0.0,
#   'somebody': 0.0,
#   'meant': 0.0,
#   'asked': 0.0,
#   'please': 0.0,
#   'partner': 0.0,
#   'jamaica': 0.0,
#   'pack': 0.0,
#   'lows': 0.0,
#   'thirty': 0.0,
#   'reside': 0.0,
#   'hittas': 0.0,
#   'ship': 0.0,
#   'huh': 0.0,
#   'eyy': 0.0,
#   'patois': 0.0,
#   'smoke': 2.302585092994046,
#   'squad': 0.0,
#   'princeturnedpope': 0.0,
#   'everlasting': 0.0,
#   'juggin': 0.0,
#   'hollow': 0.0,
#   'mopped': 0.0,
#   'aftermath': 0.0,
#   'games': 0.0,
#   'write': 0.0,
#   'passengers': 0.0,
#   'nerve': 0.0,
#   'lawless': 0.0,
#   'remote': 0.0,
#   'survive': 0.0,
#   'gas': 0.0,
#   'mayhem': 0.0,
#   'blah': 0.0,
#   'double': 0.0,
#   'thank': 0.0,
#   'lox': 0.0,
#   'cleaning': 0.0,
#   'closed': 0.0,
#   'whats': 0.0,
#   'scope': 0.0,
#   'first': 0.0,
#   'lights': 0.0,
#   'organized': 0.0,
#   'general': 0.0,
#   'planes': 0.0,
#   'everybody': 0.0,
#   'anderson': 0.0,
#   'kings': 0.0,
#   'claimed': 0.0,
#   'caution': 0.0,
#   'blood': 9.210340371976184,
#   'devoted': 0.0,
#   'bypass': 0.0,
#   'dough': 0.0,
#   'war': 2.302585092994046,
#   'russians': 0.0,
#   'del': 0.0,
#   'acquitted': 0.0,
#   'agua': 0.0,
#   'absoul': 0.0,
#   'dark': 0.0,
#   'dirty': 0.0,
#   'low': 0.0,
#   'hot': 0.0,
#   'mando': 0.0,
#   'buried': 0.0,
#   'stealing': 0.0,
#   'depart': 0.0,
#   ...}]

# %% [markdown]
# ### Level Up: Visualizing our Vectorizations (Optional)
#
# Now that we have a tf-idf representation of each document, we can move on to the fun part -- visualizing everything!
#
# In the cell below, examine our dictionaries to figure out how many dimensions our dataset has.
#
# **_HINT_**: Remember that every word is its own dimension!

# %%
all_words = set()

for tf_idf_vector in tf_idf_all_docs:
    all_words.update(tf_idf_vector.keys())
num_dims = len(all_words)
print(f"Number of Dimensions: {num_dims}")
# Out:
# Number of Dimensions: 1372

# %% [markdown]
# There are too many dimensions for us to visualize! In order to make it understandable to human eyes, we'll need to reduce it to 2 or 3 dimensions.
#
# To do this, we'll use a technique called **_t-SNE_** (short for _t-Stochastic Neighbors Embedding_).  This is too complex for us to code ourselves, so we'll make use of scikit-learn's implementation of it.
#
# First, we need to pull the words out of the dictionaries stored in `tf_idf_all_docs` so that only the values remain, and store them in lists instead of dictionaries.  This is because the t-SNE only works with array-like objects, not dictionaries.
#
# In the cell below, create a list of lists that contains a list representation of the values of each of the dictionaries stored in `tf_idf_all_docs`.  The same structure should remain -- e.g. the first list should contain only the values that were in the first dictionary in `tf_idf_all_docs`, and so on.

# %%
tf_idf_vals_list = [list(tf_idf_vector.values()) for tf_idf_vector in tf_idf_all_docs]

tf_idf_vals_list[0][:10]
# Out:
# [8.987196820661973,
#  2.995732273553991,
#  2.995732273553991,
#  8.987196820661973,
#  1.8971199848858813,
#  2.995732273553991,
#  1.8971199848858813,
#  1.2039728043259361,
#  8.987196820661973,
#  2.302585092994046]

# %% [markdown]
# Now that we have only the values, we can use the `TSNE()` class from `sklearn` to transform our data appropriately. In the cell below, instantiate `TSNE()` with the following arguments:
# - `n_components=3` (so we can compare 2 vs 3 components when graphing)
# - `perplexity=19` (the highest number of neighbors explored given the size of our dataset)
# - `learning_rate=200` (a higher learning rate than using 'auto', to avoid getting stuck in a local minimum)
# - `init='random'` (so SKLearn will randomize the initialization)
# - `random_state=13` (so that random initialization won't be TOO random)
#
# Then, use the created object's `.fit_transform()` method to transform the data stored in `tf_idf_vals_list` into 3-dimensional data.  Then, inspect the newly transformed data to confirm that it has the correct dimensionality.

# %%
t_sne_object_3d = TSNE(n_components=3, perplexity=19, learning_rate=200, init='random', random_state=13)

transformed_data_3d = t_sne_object_3d.fit_transform(np.array(tf_idf_vals_list))
transformed_data_3d
# Out:
# array([[ 162.07677  ,  -33.605713 , -333.08868  ],
#        [-111.911674 ,   42.087135 ,  174.51202  ],
#        [ 232.12892  ,  -30.52421  ,   -3.9418073],
#        [  80.88284  ,  120.75108  ,  211.25917  ],
#        [ 163.68985  ,  187.13487  ,   15.714809 ],
#        [-220.96848  ,  192.33403  ,   90.380226 ],
#        [-197.21852  , -230.34465  , -184.61804  ],
#        [ 273.3781   ,   26.462706 ,  198.03702  ],
#        [-121.117714 ,   63.672146 ,  -53.45145  ],
#        [ -37.291306 , -141.1573   , -110.76769  ],
#        [-285.46487  ,  -49.28679  ,  -54.310085 ],
#        [ -30.829008 ,  -32.070004 , -274.22406  ],
#        [  31.716951 ,  -29.701965 ,   36.56184  ],
#        [-556.66144  ,  229.13504  ,  995.0731   ],
#        [ -94.4783   , -231.89589  ,   70.06137  ],
#        [  94.58625  ,   81.37662  , -149.44174  ],
#        [-122.52384  ,  196.63853  , -207.90556  ],
#        [ 140.21414  , -227.9537   ,    4.6486654],
#        [  15.937845 , -118.82148  ,  237.29199  ],
#        [ -28.390652 ,  270.87674  ,   -7.27854  ]], dtype=float32)

# %% [markdown]
# We'll also want to check out how the visualization looks in 2d.  Repeat the process above, but this time, instantiate `TSNE()` with 2 components instead of 3.  Again, use `.fit_transform()` to transform the data and store it in the variable below, and then inspect it to confirm the transformed data has only 2 dimensions.

# %%
t_sne_object_2d = TSNE(n_components=2, perplexity=19, learning_rate=200, init='random', random_state=13)

transformed_data_2d = t_sne_object_2d.fit_transform(np.array(tf_idf_vals_list))
transformed_data_2d
# Out:
# array([[  14.577086 , -189.47237  ],
#        [ 144.49672  ,  -55.9761   ],
#        [  22.12635  ,  206.61354  ],
#        [-165.96643  ,   88.43282  ],
#        [ -95.60857  , -163.20988  ],
#        [ 237.02248  ,    2.5355406],
#        [  -8.513989 ,   12.380647 ],
#        [ -92.756874 ,  189.87827  ],
#        [ 145.96315  ,   63.718678 ],
#        [  49.781796 ,  -90.11695  ],
#        [ -45.357746 ,  100.49586  ],
#        [ 226.85876  , -117.24749  ],
#        [  75.95313  ,    3.9357824],
#        [ 130.12453  ,  180.67397  ],
#        [-169.70844  ,  -66.69064  ],
#        [ -43.768475 ,  -77.12288  ],
#        [  52.414715 ,  102.62648  ],
#        [-102.67916  ,    8.708147 ],
#        [ 231.16855  ,  121.869545 ],
#        [ 123.422676 , -171.69832  ]], dtype=float32)

# %% [markdown]
# Now, let's visualize everything!  Run the cell below to view both 3D and 2D visualizations of the songs.

# %%
kendrick_3d = transformed_data_3d[:10]
k3_x = [i[0] for i in kendrick_3d]
k3_y = [i[1] for i in kendrick_3d]
k3_z = [i[2] for i in kendrick_3d]

garth_3d = transformed_data_3d[10:]
g3_x = [i[0] for i in garth_3d]
g3_y = [i[1] for i in garth_3d]
g3_z = [i[2] for i in garth_3d]

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(k3_x, k3_y, k3_z, c='b', s=60, label='Kendrick')
ax.scatter(g3_x, g3_y, g3_z, c='red', s=60, label='Garth')
ax.view_init(40,10)
ax.legend()
plt.show()

kendrick_2d = transformed_data_2d[:10]
k2_x = [i[0] for i in kendrick_2d]
k2_y = [i[1] for i in kendrick_2d]

garth_2d = transformed_data_2d[10:]
g2_x = [i[0] for i in garth_2d]
g2_y = [i[1] for i in garth_2d]

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(222)
ax.scatter(k2_x, k2_y, c='b', label='Kendrick')
ax.scatter(g2_x, g2_y, c='red', label='Garth')
ax.legend()
plt.show()

# %% [markdown]
# Interesting! Take a crack at interpreting these graphs by answering the following questions below:
#
# What does each graph mean? Do you find one graph more informative than the other? Do you think that this method shows us discernable differences between Kendrick Lamar songs and Garth Brooks songs?  Use the graphs and your understanding of TF-IDF to support your answer.

# %%
'''
The 3D graph shows a more detailed representation of the songs, with Kendrick Lamar's and Garth Brooks' songs clustering separately, indicating distinct vocabulary usage between the two artists. 
The 2D graph simplifies this view, making it easier to spot overall patterns but losing some detail. 
Both graphs suggest that the TF-IDF vectorization captures the differences in word distributions between Kendrick Lamar and Garth Brooks, with the 3D graph offering a clearer, more nuanced view. 
Overall, both visualizations highlight discernible differences between the artists' lyrics.
'''
# Out:
# "\nThe 3D graph shows a more detailed representation of the songs, with Kendrick Lamar's and Garth Brooks' songs clustering separately, indicating distinct vocabulary usage between the two artists. \nThe 2D graph simplifies this view, making it easier to spot overall patterns but losing some detail. \nBoth graphs suggest that the TF-IDF vectorization captures the differences in word distributions between Kendrick Lamar and Garth Brooks, with the 3D graph offering a clearer, more nuanced view. \nOverall, both visualizations highlight discernible differences between the artists' lyrics.\n"

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to:
# * Tokenize a corpus of words and identify the different choices to be made while parsing them
# * Use a count vectorization strategy to create a bag of words
# * Use TF-IDF vectorization with multiple documents to identify words that are important/unique to certain documents
# * Visualize and compare vectorized text documents
